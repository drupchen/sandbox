# %% [markdown]
# # Hill Lexicon

# %%
with open('./2016-04-06-lexicon.txt', 'r', -1, 'utf-8-sig') as f:
    content = [line.strip() for line in f.readlines()]

# %%
lexicon = {}
for line in content:
    parts = line.split('\t')
    entry = parts[0]
    pos = [elt.strip(' -') for elt in parts[1:]]
    if entry.endswith('་'):
        entry = entry[:-1]
    if entry in lexicon.keys():
        for p in pos:
            if p not in lexicon[entry]:
                lexicon[entry].append(p)
    else:
        lexicon[entry] = pos

# %%
flat_lexicon = {}
for entry in lexicon.keys():
    flat_lexicon[entry] = '_'.join(lexicon[entry])

# %%
pos_list = []
for entry in lexicon.keys():
    pos_list.extend(lexicon[entry])
pos_set = set(pos_list)

# %%
print(sorted(pos_set))

# %%
with open('hill_lexicon.txt', 'w', -1, 'utf-8-sig') as f:
    for entry in no_prop.keys():
        f.write(entry+'***'+no_prop[entry]+'\n')

# %%
cases = {}
for entry in flat_lexicon.keys():
    pos = flat_lexicon[entry]
    if 'case' in pos and 'cv' not in pos:
        print('nocv: ', entry, pos)
    #elif 'case' not in pos and 'cv' in pos:
     #   print('nocase: ', entry, pos)

# %%
for entry in flat_lexicon.keys():
    pos = flat_lexicon[entry]
    if 'case' not in pos and 'cv' in pos:
        print('nocase: ', entry, pos)

# %%
no_prop = {}
prop = []
for entry in flat_lexicon.keys():
    pos = flat_lexicon[entry]
    if 'prop' in pos:
        prop.append(entry)
    else:
        no_prop[entry] = pos

# %%
print(prop)

# %%
len(one_pos)

# %%
len(flat_lexicon)

# %%
22279-15963

# %%
6316*100/22279

# %% [markdown]
# # Monlam Lexicon

# %% [markdown]
# ## From xml

# %%
from bs4 import BeautifulSoup as Soup

# %%
import re

# %%
with open('monlamTb1.xml', 'r', -1, 'utf-8-sig') as f:
    monlam = f.read()

# %%
soup = Soup(monlam, 'lxml')

# %%
dicts = soup.array.findAll('dict')

# %%
monlam_dict = []
for dic in dicts:
    entry = dic.find_all('string')
    lemma = entry[0].string
    descr = entry[1].string.replace('\n', '')
    monlam_dict.append(lemma+' | '+descr)

# %%
with open('./monlam/monlam1_total.txt', 'w', -1, 'utf-8-sig') as f:
    f.write('\n'.join(monlam_dict))

# %% [markdown]
# ## From txt

# %%
with open('./monlam/monlam1_total.txt','r', -1, 'utf-8-sig') as f:
    content0 = [line.strip() for line in f.readlines()]

# %% [markdown]
# ### find all Categories

# %%
combined_entries = []
for line in content0:
    # separate the entry and the description
    parts = line.split(' | ')
    lemma = parts[0].strip()
    #print(lemma, end = ' ')
    # separate all sub-entries
    sub_entries = re.split(r'༡(མིང|བྱ|རྒྱན|བསྣན|ཚབ|མཚུངས|སྒྲུབ|ཕྲད|འབོད|གྲངས|འཇལ|གྲོགས)་ཚིག', parts[1])
    tags = ''
    for i in range(1, len(sub_entries), 2):
        tags += sub_entries[i]+'+'
    if tags not in combined_entries:
        combined_entries.append(tags)
        if tags == '':
            print(line)

# %%
print(combined_entries)
for e in combined_entries:
    plus = re.findall('\+', e)
    print(plus)

# %% [markdown]
# ### POS

# %% [markdown]
# ### correct missing tags

# %%
# list all the pos by looking at the 
pos = []
for line in content0:
    tags = re.findall(r' [༡༢][^ ༡༢༣༤༥༦༧༨༩༠.༽]+[ །]', line)
    pos.extend(tags)
pos = sorted(set(pos))

for p in pos:
    print(p)

# %%
num_missing = []
num_inserted = []
# insert the missing number in all tags that lack it
for num, line in enumerate(content0):
    tag = re.findall(r'[། ][^༡༢](ཆོས་ལུགས།|ལོ་རྒྱུས།|ལྟ་གྲུབ།|རྩོམ་རིག|གསོ་རིག|ཆབ་སྲིད།|ཚན་རིག|བཟོ་རིག|རྩིས་རིག|ཁྲིམས་ལུགས།|དཔལ་འབྱོར།|དམག་དོན།|འཛིན་སྐྱོང་།|སྒྲ་རིག་པ།|ཤེས་ཡོན།|སློབ་གསོ།|ཚད་མ།|ཚད་མ་རིག་པ།|སྐྱེ་དངོས་རིག་པ།|ཟུར་ཆག|རྒྱ་གར།|རྒྱ་ནག|རྒྱ་ནག།|སོག་པོ།|མན་ཇུ།|དབྱིན་ཇི།|བལ་བོ།|མིང་གི་རྣམ་གྲངས།|མིང་གི་གྲངས།|མིང་གི་རྣམ་གྲངས་ལ།|ལྡོག་ཚིག|ལྡོག་ཚིིག|ལྡོག་ཚིག|ཉེ་ཚིག|ཟུར་མཆན།|ཡུལ་སྐད།|ཞེ་ས།|བརྙས་ཚིག|ལོག་སྐད།|དཔེ་ཆོས།|མངོན་བརྗོད།|བརྡ་རྙིང་།|བསྡུས་ཚིག|རྒྱུན་སྤྱོད།|བསྡུར་རིམ།|མ་འོངས་པ།|མ་འོངས།|ད་ལྟ་བ་།|ད་ལྟ་བ།|འདས་པ།|འདས།|སྐུ་ཚིག|སྐུར་ཚིག|སྐུལ་ཚིག|སྐུལ་ཚིག།|སྐུུལ་ཚིག) ', line)
    if tag != []:
        truc = re.sub(r'([^༡༢])(ཆོས་ལུགས།|ལོ་རྒྱུས།|ལྟ་གྲུབ།|རྩོམ་རིག|གསོ་རིག|ཆབ་སྲིད།|ཚན་རིག|བཟོ་རིག|རྩིས་རིག|ཁྲིམས་ལུགས།|དཔལ་འབྱོར།|དམག་དོན།|འཛིན་སྐྱོང་།|སྒྲ་རིག་པ།|ཤེས་ཡོན།|སློབ་གསོ།|ཚད་མ།|ཚད་མ་རིག་པ།|སྐྱེ་དངོས་རིག་པ།|ཟུར་ཆག|རྒྱ་གར།|རྒྱ་ནག|རྒྱ་ནག།|སོག་པོ།|མན་ཇུ།|དབྱིན་ཇི།|བལ་བོ།|མིང་གི་རྣམ་གྲངས།|མིང་གི་གྲངས།|མིང་གི་རྣམ་གྲངས་ལ།|ལྡོག་ཚིག|ལྡོག་ཚིིག|ལྡོག་ཚིག|ཉེ་ཚིག|ཟུར་མཆན།|ཡུལ་སྐད།|ཞེ་ས།|བརྙས་ཚིག|ལོག་སྐད།|དཔེ་ཆོས།|མངོན་བརྗོད།|བརྡ་རྙིང་།|བསྡུས་ཚིག|རྒྱུན་སྤྱོད།|བསྡུར་རིམ།|མ་འོངས་པ།|མ་འོངས།|ད་ལྟ་བ་།|ད་ལྟ་བ།|འདས་པ།|འདས།|སྐུ་ཚིག|སྐུར་ཚིག|སྐུལ་ཚིག|སྐུལ་ཚིག།|སྐུུལ་ཚིག) ', r'\1༡\2 ', line)
        num_inserted.append(str(num)+truc)
        num_missing.append(str(num)+line)
with open('monlam_num_missing.txt', 'w', -1, 'utf-8-sig') as f:
    for line in num_missing:
        f.write(line+'\n')
with open('monlam_num_inserted.txt', 'w', -1, 'utf-8-sig') as f:
    for line in num_inserted:
        f.write(line+'\n')

# %% [markdown]
# to do : compare in Meld the two, put a '*' at the beginning of each line where the ༡ is not necessary, and delete the extra ones in lines where needed. Save the files in the monlam folder to not risk delete the work.

# %%
with open('./monlam/monlam_num_inserted.txt', 'r', -1, 'utf-8-sig') as f:
    inserted = [line.strip() for line in f.readlines()]
monlam_corrected = content0

# replace the bad entries by the ones from monlam_num_inserted.txt
for line in inserted:
    if not line.startswith('*'):
        entry = [i for i in re.split('^([0-9]+)', line) if i != '']
        monlam_corrected[int(entry[0])] = entry[1]

with open('monlam1_total_corrected.txt', 'w', -1, 'utf-8-sig') as f:
    for line in monlam_corrected:
        f.write(line+'\n')

# %%
with open('monlam1_total_corrected.txt', 'r', -1, 'utf-8-sig') as f:
    content1 = [line.strip() for line in f.readlines()]

# %% [markdown]
#  Insert the modifications in monlam_errors.txt and save the file. The file is ready to be parsed !

# %% [markdown]
# ### Verbs

# %%
verbs = []
rest = []
for line in content1:
    if '༡བྱ་ཚིག' in line and '༡རྒྱ་གར།' not in line:
        verbs.append(line)
    else:
        rest.append(line)

# %%
def isRef(string):
    test = False
    if re.findall(r'[^༡༢](མ་འོངས་པ།|ད་ལྟ་བ།|འདས་པ།|སྐུལ་ཚིག)', string):
        test = True
    return test

# %%
def add2dict(key, value, dic):
    if key not in dic.keys():
        dic[key] = value
    else:
        dic[key] = list(set(dic[key] + value))

# %%
thadepa = 'ཐ་དད་པ'
thamidepa = 'ཐ་མི་དད་པ'
zugmigyur = 'གཟུགས་མི་འགྱུར་བ'
empty = '###'
unknown = 'བྱ་ཚིག'
attr_sep = '_'
pos_sep = '+'

verbs_dict = {}
for verb in verbs:
    # separate the entry and the description
    parts = verb.split(' | ')
    lemma = parts[0].strip().replace('་', '')
    
    # separate all sub-entries
    sub_entries = re.split(r'༡(མིང|བྱ|རྒྱན|བསྣན|ཚབ|མཚུངས|སྒྲུབ|ཕྲད|འབོད|གྲངས|འཇལ|གྲོགས)་ཚིག', parts[1])
    # only keep the verb sub-entry
    sub = ''
    for i in range(len(sub_entries)):
        if sub_entries[i] == 'བྱ':
            sub = sub_entries[i+1]
    
    # separate meanings
    meanings = re.split(r' [0-9]+\. ', sub)
    
    # keep only verbs that are not references
    #new_meanings = [m.strip() for m in meanings if not isRef(m) and m != '']
    new_meanings = [m.strip() for m in meanings if m != '']
    
    if new_meanings != []:
        for meaning in new_meanings:
            #print(lemma, meaning)
            # ཐ་དད་པ་ or ཐ་མི་དད་པ་
            tha = empty
            
            if  'བྱ་བྱེད་ཐ་མི་དད་པ། ' in meaning: tha = thamidepa
            elif 'བྱ་བྱེད་ཐ་དད་པ། ' in meaning: tha = thadepa
            
            # tenses
            if ' གཟུགས་མི་འགྱུར་བ། ' in meaning:
                add2dict(lemma, [zugmigyur+attr_sep+tha], verbs_dict)
                #print({lemma : zugmigyur+attr_sep+tha})
            else:
                if 'མ་འོངས་པ།' in meaning or 'ད་ལྟ་བ།' in meaning or 'འདས་པ།' in meaning or 'སྐུལ་ཚིག' in meaning:
                    tenses = re.findall(r'.(མ་འོངས་པ།|མ་འོངས།) ([^་\s]+་?[ག།]) .(ད་ལྟ་བ་།|ད་ལྟ་བ།|ལྟ་བ།) ([^་\s]+་?[ག།]) .(འདས་པ།|འདས།) ([^་\s]+་?[ག།]) ?.?(སྐུ་ཚིག|སྐུར་ཚིག|སྐུལ་ཚིག|སྐུལ་ཚིག།|སྐུུལ་ཚིག)? ?([^་\s]+་?[ག།])?', meaning)

                    ############################
                    # hack because of a strange behaviour of python : the structure of tenses is a tuple embedded in a list
                    for t in tenses: 
                        temp = []
                        for elt in t:
                            if elt != '':
                                temp.append(elt)
                    tenses = temp
                    #
                    ############################

                    #print(tenses)
                    for i in range(0, len(tenses)-1, 2):
                        inflected = tenses[i+1].replace('།', '').replace('་', '')
                        tense = tenses[i]
                        add2dict(inflected, [lemma+attr_sep+tense+attr_sep+tha], verbs_dict)
                        #print({inflected : lemma+attr_sep+tense+attr_sep+tha})
                    # empty the tenses list for the next verb
                    tenses = []
                else:
                    add2dict(lemma, [unknown+attr_sep+tha], verbs_dict)
                    #print({lemma : unknown+attr_sep+tha})

# %%
# flatten the pos list into a string
for v in verbs_dict.keys():
    flattened = '+'.join(verbs_dict[v])
    verbs_dict[v] = flattened

# %%
with open('monlam1_verbs.txt', 'w', -1, 'utf-8-sig') as f:
    for verb in sorted(verbs_dict.keys()):
        f.write(verb+' | '+verbs_dict[verb]+'\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-56e22e01a3a1> in <module>()
#       1 with open('monlam1_verbs.txt', 'w', -1, 'utf-8-sig') as f:
#       2     for verb in sorted(verbs_dict.keys()):
# ----> 3         f.write(verb+' | '+verbs_dict[verb]+'\n')
#
# TypeError: Can't convert 'list' object to str implicitly

# %% [markdown]
# ## Other tags

# %%
for entry in content1:
    # separate the entry and the description
    parts = entry.split(' | ')
    lemma = parts[0].strip().replace('་', '')
    
    # separate all sub-entries
    sub_entries = re.split(r'༡(མིང|བྱ|རྒྱན|བསྣན|ཚབ|མཚུངས|སྒྲུབ|ཕྲད|འབོད|གྲངས|འཇལ|གྲོགས)་ཚིག', parts[1])
    
    # only keep the verb sub-entry
    sub = []
    for i in range(len(sub_entries)):
        if sub_entries[i] == 'བྱ' and '༡རྒྱ་གར།' not in sub_entries[i+1]:
            sub.append('བྱ་ཚིག:'+verbs_dict[lemma])
    if sub != []:
        print(lemma, sub)
# Out:
# ཀུམ ['བྱ་ཚིག:བྱ་ཚིག_###+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཀེར ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཀྲུགས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཀླན ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# ཀླལ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཀླས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# ཀླུབ ['བྱ་ཚིག:ཀླུབ_ད་ལྟ་བ།_ཐ་དད་པ+བཀླུབས_ད་ལྟ་བ།_ཐ་དད་པ+བཀླུབ_ད་ལྟ་བ།_ཐ་དད་པ+ཀླུབས_ད་ལྟ་བ།_ཐ་དད་པ']
# ཀླུབས ['བྱ་ཚིག:ཀླུབས_སྐུལ་ཚིག_ཐ་དད་པ+བཀླུབས_སྐུལ་ཚིག_ཐ་དད་པ+བཀླུབ_སྐུལ་ཚིག_ཐ་དད་པ+ཀླུབ_སྐུལ་ཚིག_ཐ་དད་པ']
# ཀློག ['བྱ་ཚིག:ཀློག_ད་ལྟ་བ།_ཐ་དད་པ+བཀླག_ད་ལྟ་བ།_ཐ་དད་པ+བཀླགས_ད་ལྟ་བ།_ཐ་དད་པ+ཀློགས_ད་ལྟ་བ།_ཐ་དད་པ']
# ཀློགས ['བྱ་ཚིག:བཀླགས_སྐུལ་ཚིག_ཐ་དད་པ+ཀློག_སྐུལ་ཚིག_ཐ་དད་པ+བཀླག_སྐུལ་ཚིག_ཐ་དད་པ+ཀློགས_སྐུལ་ཚིག_ཐ་དད་པ']
# ཀློད ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# ཁུག ['བྱ་ཚིག:ཁུག_སྐུལ་ཚིག_ཐ་དད་པ+དགུག_སྐུལ་ཚིག_ཐ་དད་པ+བཀུག_སྐུལ་ཚིག_ཐ་དད་པ+འགུགས_སྐུལ་ཚིག_ཐ་དད་པ+ཁུག_ད་ལྟ་བ།_ཐ་མི་དད་པ+ཁུགས_ད་ལྟ་བ།_ཐ་མི་དད་པ+ཁུགས_མ་འོངས་པ།_ཐ་མི་དད་པ+ཁུག_མ་འོངས་པ།_ཐ་མི་དད་པ+འགུགས_སྐུལ་ཚིག_###']
# ཁུགས ['བྱ་ཚིག:ཁུག_འདས་པ།_ཐ་མི་དད་པ+ཁུགས_འདས་པ།_ཐ་མི་དད་པ']
# ཁུན ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁུམ ['བྱ་ཚིག:བཀུམ_སྐུལ་ཚིག_ཐ་དད་པ+འགུམ_སྐུལ་ཚིག_ཐ་དད་པ+དགུམ_སྐུལ་ཚིག_ཐ་དད་པ+ཁུམ_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁུམས ['བྱ་ཚིག:བྱ་ཚིག_ཐ་མི་དད་པ']
# ཁུར ['བྱ་ཚིག:འཁུར_སྐུལ་ཚིག_ཐ་དད་པ+འཁུར_འདས་པ།_ཐ་དད་པ+ཁུར_སྐུལ་ཚིག_ཐ་དད་པ+ཁུར_འདས་པ།_ཐ་དད་པ']
# ཁེ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁེག ['བྱ་ཚིག:ཁེག_མ་འོངས་པ།_ཐ་མི་དད་པ+ཁེགས_མ་འོངས་པ།_ཐ་མི་དད་པ+ཁེགས_ད་ལྟ་བ།_ཐ་མི་དད་པ+ཁེག_ད་ལྟ་བ།_ཐ་མི་དད་པ']
# ཁེགས ['བྱ་ཚིག:ཁེག_འདས་པ།_ཐ་མི་དད་པ+ཁེགས_འདས་པ།_ཐ་མི་དད་པ']
# ཁེང ['བྱ་ཚིག:ཁེང_ད་ལྟ་བ།_###+ཁེང_མ་འོངས་པ།_ཐ་མི་དད་པ+ཁེང_མ་འོངས་པ།_###+ཁེངས_ད་ལྟ་བ།_ཐ་མི་དད་པ+ཁེངས_མ་འོངས་པ།_ཐ་མི་དད་པ+ཁེང_ད་ལྟ་བ།_ཐ་མི་དད་པ']
# ཁེངས ['བྱ་ཚིག:ཁེང_འདས་པ།_ཐ་མི་དད་པ+ཁེང_འདས་པ།_###+ཁེངས_འདས་པ།_ཐ་མི་དད་པ']
# ཁེད ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁེན ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁེབ ['བྱ་ཚིག:ཁེབས_ད་ལྟ་བ།_ཐ་མི་དད་པ+ཁེབ_མ་འོངས་པ།_ཐ་མི་དད་པ+ཁེབས_མ་འོངས་པ།_ཐ་མི་དད་པ+ཁེབ_ད་ལྟ་བ།_ཐ་མི་དད་པ']
# ཁེབས ['བྱ་ཚིག:ཁེབ_འདས་པ།_ཐ་མི་དད་པ+ཁེབས_འདས་པ།_ཐ་མི་དད་པ']
# ཁེར ['བྱ་ཚིག:བྱ་ཚིག_###']
# ཁེལ ['བྱ་ཚིག:ཁེལ_འདས་པ།_ཐ་མི་དད་པ+ཁོལ_འདས་པ།_###+འཁོད_འདས་པ།_ཐ་དད་པ+འཁེལ_འདས་པ།_###']
# ཁོག ['བྱ་ཚིག:དགག_སྐུལ་ཚིག_ཐ་དད་པ+འགོག_སྐུལ་ཚིག_ཐ་དད་པ+བཀག_སྐུལ་ཚིག_ཐ་དད་པ+བཀོག_སྐུལ་ཚིག_ཐ་དད་པ+འགོག_སྐུལ་ཚིག_###+ཁོག_སྐུལ་ཚིག_ཐ་དད་པ+དགོག_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁོང ['བྱ་ཚིག:བཀང_སྐུལ་ཚིག_ཐ་དད་པ+ཁོང_སྐུལ་ཚིག_ཐ་དད་པ+དགང_སྐུལ་ཚིག_ཐ་དད་པ+འགེངས_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁོད ['བྱ་ཚིག:འགོད_སྐུལ་ཚིག_ཐ་དད་པ+ཁོད_སྐུལ་ཚིག_ཐ་དད་པ+འགད_སྐུལ་ཚིག_ཐ་དད་པ+དགོད_སྐུལ་ཚིག_###+བཀོད_སྐུལ་ཚིག_ཐ་དད་པ+དགད_སྐུལ་ཚིག_ཐ་དད་པ+བཀད_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁོན ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁོབ ['བྱ་ཚིག:འགེབ_སྐུལ་ཚིག_###+འགེབ_སྐུལ་ཚིག_ཐ་དད་པ+དགབ_སྐུལ་ཚིག_ཐ་དད་པ+ཁོབ_སྐུལ་ཚིག_ཐ་དད་པ+བཀབ_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁོར ['བྱ་ཚིག:བཀར_སྐུལ་ཚིག_###+འགེལ_སྐུལ་ཚིག_ཐ་དད་པ+ཁོར_སྐུལ་ཚིག_###+འགེར_སྐུལ་ཚིག_###+དགར_སྐུལ་ཚིག_ཐ་དད་པ+འགེར_སྐུལ་ཚིག_ཐ་དད་པ+ཁོར_སྐུལ་ཚིག_ཐ་དད་པ+བཀར_སྐུལ་ཚིག_ཐ་དད་པ+དགར_སྐུལ་ཚིག_###']
# ཁོལ ['བྱ་ཚིག:དགོལ_སྐུལ་ཚིག_ཐ་དད་པ+འཁོལ_སྐུལ་ཚིག_###+དགལ_སྐུལ་ཚིག_ཐ་དད་པ+བཀལ_སྐུལ་ཚིག_ཐ་དད་པ+འཁེལ_སྐུལ་ཚིག_ཐ་དད་པ+ཁོལ_འདས་པ།_###+བཀོལ_སྐུལ་ཚིག_ཐ་དད་པ+འཁོལ_སྐུལ་ཚིག_ཐ་དད་པ+འཁོལ_ད་ལྟ་བ།_ཐ་མི་དད་པ+འཁོལ_འདས་པ།_ཐ་མི་དད་པ+འཁེལ_སྐུལ་ཚིག_###+བཀལ_སྐུལ་ཚིག_###+ཁོལ_སྐུལ་ཚིག_ཐ་དད་པ+ཁོལ_འདས་པ།_ཐ་མི་དད་པ+འགེལ_སྐུལ་ཚིག_###+ཁོལ_ད་ལྟ་བ།_ཐ་མི་དད་པ+ཁེལ_སྐུལ་ཚིག_ཐ་མི་དད་པ+ཁོལ_སྐུལ་ཚིག_###']
# ཁོས ['བྱ་ཚིག:འགས_སྐུལ་ཚིག_ཐ་དད་པ+བཀས_སྐུལ་ཚིག_ཐ་དད་པ+དགས_སྐུལ་ཚིག_ཐ་དད་པ+ཁོས_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁྱག ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# ཁྱགས ['བྱ་ཚིག:བྱ་ཚིག_ཐ་མི་དད་པ']
# ཁྱབ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁྱིགས ['བྱ་ཚིག:འཁྱིག_སྐུལ་ཚིག_ཐ་དད་པ+ཁྱིགས_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁྱེ ['བྱ་ཚིག:ཁྱེས_མ་འོངས་པ།_ཐ་དད་པ+ཁྱེས_ད་ལྟ་བ།_ཐ་དད་པ+ཁྱེ_མ་འོངས་པ།_ཐ་དད་པ+ཁྱེ_ད་ལྟ་བ།_ཐ་དད་པ']
# ཁྱེད ['བྱ་ཚིག:དགྱེད_སྐུལ་ཚིག_ཐ་དད་པ+འགྱེད_སྐུལ་ཚིག_###+བཀྱེད_སྐུལ་ཚིག_ཐ་དད་པ+ཁྱེད_སྐུལ་ཚིག_ཐ་དད་པ+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁྱེར ['བྱ་ཚིག:འཁྱེར_འདས་པ།_ཐ་དད་པ+ཁྱེར_སྐུལ་ཚིག_ཐ་དད་པ+འཁྱེར_སྐུལ་ཚིག_ཐ་དད་པ+ཁྱེར_འདས་པ།_ཐ་དད་པ']
# ཁྱེས ['བྱ་ཚིག:ཁྱེས_འདས་པ།_ཐ་དད་པ+འགྱེད_སྐུལ་ཚིག_###+ཁྱེ_འདས་པ།_ཐ་དད་པ+ཁྱེ_སྐུལ་ཚིག_ཐ་དད་པ+བཀྱེས_སྐུལ་ཚིག_ཐ་དད་པ+འགྱེད_སྐུལ་ཚིག_ཐ་དད་པ+ཁྱེས_སྐུལ་ཚིག_ཐ་དད་པ+བཀྱེ_སྐུལ་ཚིག_ཐ་དད་པ+ཁྱེས_སྐུལ་ཚིག_###']
# ཁྱོག ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ+བཀྱགས_ད་ལྟ་བ།_###+ཁྱོག_ད་ལྟ་བ།_ཐ་དད་པ+ཁྱོགས_ད་ལྟ་བ།_###']
# ཁྱོགས ['བྱ་ཚིག:བཀྱག_སྐུལ་ཚིག_ཐ་དད་པ+འགྱོག_སྐུལ་ཚིག_ཐ་དད་པ+བཀྱགས_སྐུལ་ཚིག_ཐ་དད་པ+ཁྱོགས_སྐུལ་ཚིག_###+ཁྱོགས_སྐུལ་ཚིག_ཐ་དད་པ+བཀྱགས_སྐུལ་ཚིག_###+ཁྱོག_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁྲིད ['བྱ་ཚིག:འཁྲིད_སྐུལ་ཚིག_###+ཁྲིད_འདས་པ།_ཐ་དད་པ+ཁྲིད_སྐུལ་ཚིག_ཐ་དད་པ+བཀྲི_སྐུལ་ཚིག_ཐ་དད་པ+བཀྲིས_སྐུལ་ཚིག_ཐ་དད་པ+འཁྲིད_སྐུལ་ཚིག_ཐ་དད་པ+ཁྲིད_སྐུལ་ཚིག_###+འཁྲིད_འདས་པ།_ཐ་དད་པ']
# ཁྲིལ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁྲུངས ['བྱ་ཚིག:བྱ་ཚིག_###']
# ཁྲུལ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁྲུས ['བྱ་ཚིག:འཁྲུད_སྐུལ་ཚིག_ཐ་དད་པ+བཀྲུས_སྐུལ་ཚིག_ཐ་དད་པ+བཀྲུ_སྐུལ་ཚིག_ཐ་དད་པ+བཀྲུམས_སྐུལ་ཚིག_ཐ་དད་པ+ཁྲུས_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁྲེམས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁྲེལ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁྲོ ['བྱ་ཚིག:ཁྲོ_མ་འོངས་པ།_ཐ་མི་དད་པ+ཁྲོས_མ་འོངས་པ།_ཐ་དད་པ+ཁྲོ_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཅག_ད་ལྟ་བ།_ཐ་དད་པ+གཅག_མ་འོངས་པ།_ཐ་དད་པ+ཁྲོས_ད་ལྟ་བ།_ཐ་དད་པ']
# ཁྲོག ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# ཁྲོབ ['བྱ་ཚིག:དཀྲབ_སྐུལ་ཚིག_ཐ་དད་པ+འཁྲབ_སྐུལ་ཚིག_ཐ་དད་པ+ཁྲོབ_སྐུལ་ཚིག_ཐ་དད་པ+ཁྲོབས_སྐུལ་ཚིག_ཐ་དད་པ+བཀྲབ_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁྲོབས ['བྱ་ཚིག:དཀྲབ_སྐུལ་ཚིག_ཐ་དད་པ+འཁྲབ_སྐུལ་ཚིག_ཐ་དད་པ+ཁྲོབ_སྐུལ་ཚིག_ཐ་དད་པ+ཁྲོབས_སྐུལ་ཚིག_ཐ་དད་པ+བཀྲབ_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁྲོམ ['བྱ་ཚིག:ཁྲོམ_སྐུལ་ཚིག_ཐ་དད་པ+འགྲེམ_སྐུལ་ཚིག_ཐ་དད་པ+བཀྲམ_སྐུལ་ཚིག_ཐ་དད་པ+དགྲམ_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁྲོལ ['བྱ་ཚིག:འཁྲོལ_སྐུལ་ཚིག_ཐ་དད་པ+བཀྲོལ_སྐུལ་ཚིག_ཐ་དད་པ+ཁྲོལ_སྐུལ་ཚིག_###+འགྲེལ_སྐུལ་ཚིག_ཐ་དད་པ+བཀྲལ_སྐུལ་ཚིག_ཐ་དད་པ+དཀྲོལ_སྐུལ་ཚིག_ཐ་དད་པ+འགྲོལ_སྐུལ་ཚིག_ཐ་དད་པ+དགྲོལ_སྐུལ་ཚིག_###+འཁྲོལ_སྐུལ་ཚིག_###+དགྲོལ_སྐུལ་ཚིག_ཐ་དད་པ+ཁྲོལ_སྐུལ་ཚིག_ཐ་དད་པ']
# ཁྲོས ['བྱ་ཚིག:གཅག_སྐུལ་ཚིག_ཐ་དད་པ+ཁྲོས_འདས་པ།_ཐ་དད་པ+ཁྲོ_འདས་པ།_ཐ་མི་དད་པ+ཁྲོས_སྐུལ་ཚིག_ཐ་དད་པ+གཅག_འདས་པ།_ཐ་དད་པ+ཁྲོ_སྐུལ་ཚིག_ཐ་མི་དད་པ']
# གང ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཅག ['བྱ་ཚིག:འཇག_མ་འོངས་པ།_ཐ་དད་པ+གཅག_མ་འོངས་པ།_ཐ་མི་དད་པ+བཅག_མ་འོངས་པ།_###+ཆོག_མ་འོངས་པ།_###+གཅོག_མ་འོངས་པ།_###+བཅག_མ་འོངས་པ།_ཐ་དད་པ+གཅོག_མ་འོངས་པ།_ཐ་དད་པ+འཇངས_མ་འོངས་པ།_ཐ་དད་པ+ཆོག_མ་འོངས་པ།_ཐ་དད་པ']
# གཅད ['བྱ་ཚིག:གཅོད_མ་འོངས་པ།_ཐ་མི་དད་པ+གཅོད_མ་འོངས་པ།_###+གཅད_མ་འོངས་པ།_ཐ་མི་དད་པ+གཅད_མ་འོངས་པ།_ཐ་དད་པ+ཆོད_མ་འོངས་པ།_ཐ་དད་པ+བཅད_མ་འོངས་པ།_ཐ་དད་པ+གཅོད_མ་འོངས་པ།_ཐ་དད་པ']
# གཅར ['བྱ་ཚིག:གཉགས_མ་འོངས་པ།_ཐ་དད་པ+གཅར_མ་འོངས་པ།_###+གཅོར_འདས་པ།_ཐ་དད་པ+གཅར_ད་ལྟ་བ།_ཐ་དད་པ+གཉག_འདས་པ།_ཐ་དད་པ+བཅར_ད་ལྟ་བ།_ཐ་དད་པ+གཅར_མ་འོངས་པ།_ཐ་དད་པ+གཅར_མ་འོངས་པ།_ཐ་མི་དད་པ+ཆོར_ད་ལྟ་བ།_ཐ་དད་པ+གཉག_ད་ལྟ་བ།_ཐ་དད་པ+གཉགས_ད་ལྟ་བ།_ཐ་དད་པ+བཅར_མ་འོངས་པ།_ཐ་དད་པ+གཉགས_འདས་པ།_ཐ་དད་པ+གཅར_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཉག_མ་འོངས་པ།_ཐ་དད་པ+གཅོར_མ་འོངས་པ།_ཐ་དད་པ+གཅོར_ད་ལྟ་བ།_ཐ་དད་པ+གཅར_འདས་པ།_ཐ་དད་པ+གཅར_ད་ལྟ་བ།_###']
# གཅི ['བྱ་ཚིག:གཅིས_མ་འོངས་པ།_ཐ་དད་པ+གཅི_མ་འོངས་པ།_ཐ་དད་པ+གཅི_ད་ལྟ་བ།_ཐ་དད་པ+གཅིས_ད་ལྟ་བ།_ཐ་དད་པ']
# གཅིར ['བྱ་ཚིག:འཆིར_མ་འོངས་པ།_###+བཅིར_མ་འོངས་པ།_ཐ་དད་པ+གཅིར_མ་འོངས་པ།_ཐ་དད་པ+འཆིར_མ་འོངས་པ།_ཐ་དད་པ+ཆིར_མ་འོངས་པ།_ཐ་དད་པ']
# གཅིལ ['བྱ་ཚིག:ཆིལ_མ་འོངས་པ།_ཐ་དད་པ+གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཅིས ['བྱ་ཚིག:གཅིས_སྐུལ་ཚིག_ཐ་དད་པ+གཅི_སྐུལ་ཚིག_ཐ་དད་པ+གཅི_འདས་པ།_ཐ་དད་པ+གཅིས_འདས་པ།_ཐ་དད་པ']
# གཅུ ['བྱ་ཚིག:གཅུས_ད་ལྟ་བ།_ཐ་དད་པ+གཅུས_མ་འོངས་པ།_ཐ་དད་པ+གཅུན_ད་ལྟ་བ།_ཐ་དད་པ+གཅུ_མ་འོངས་པ།_ཐ་དད་པ+གཅུ_ད་ལྟ་བ།_ཐ་དད་པ+གཅུན_མ་འོངས་པ།_ཐ་དད་པ']
# གཅུགས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཅུད ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཅུན ['བྱ་ཚིག:འཆུན_མ་འོངས་པ།_ཐ་དད་པ+ཆུན_མ་འོངས་པ།_ཐ་དད་པ+འཇུན_མ་འོངས་པ།_ཐ་དད་པ+བཅུན_མ་འོངས་པ།_ཐ་དད་པ']
# གཅུར ['བྱ་ཚིག:གཅུར_མ་འོངས་པ།_ཐ་དད་པ+འཇུར_མ་འོངས་པ།_ཐ་དད་པ+འཇུར_མ་འོངས་པ།_###+བཅུར_མ་འོངས་པ།_ཐ་དད་པ+ཆུར_མ་འོངས་པ།_ཐ་དད་པ']
# གཅུས ['བྱ་ཚིག:གཅུ_འདས་པ།_ཐ་དད་པ+གཅུན_སྐུལ་ཚིག_ཐ་དད་པ+གཅུན_འདས་པ།_ཐ་དད་པ+གཅུ_སྐུལ་ཚིག_ཐ་དད་པ+འཆུ_སྐུལ་ཚིག_###+འཆུས_སྐུལ་ཚིག_ཐ་དད་པ+གཅུས_སྐུལ་ཚིག_ཐ་དད་པ+གཅུས_འདས་པ།_ཐ་དད་པ']
# གཅེས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཅོག ['བྱ་ཚིག:བཅག_ད་ལྟ་བ།_ཐ་དད་པ+ཆོག_ད་ལྟ་བ།_ཐ་དད་པ+གཅོག_ད་ལྟ་བ།_ཐ་དད་པ+གཅོག_ད་ལྟ་བ།_###']
# གཅོད ['བྱ་ཚིག:གཅོད_ད་ལྟ་བ།_ཐ་དད་པ+གཅད_ད་ལྟ་བ།_ཐ་མི་དད་པ+ཆོད_ད་ལྟ་བ།_ཐ་དད་པ+བཅད_ད་ལྟ་བ།_ཐ་དད་པ+གཅད_ད་ལྟ་བ།_ཐ་དད་པ+གཅོད_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཅོད_ད་ལྟ་བ།_###']
# གཅོམ ['བྱ་ཚིག:བཅོམ_ད་ལྟ་བ།_###+བཅམས_ད་ལྟ་བ།_ཐ་དད་པ+གཅོམ_ད་ལྟ་བ།_ཐ་དད་པ']
# གཅོར ['བྱ་ཚིག:གཅོར_སྐུལ་ཚིག_ཐ་དད་པ+གཅར_སྐུལ་ཚིག_ཐ་དད་པ+གཅར_སྐུལ་ཚིག_ཐ་མི་དད་པ+བཅར_སྐུལ་ཚིག_ཐ་དད་པ+གཉག_སྐུལ་ཚིག_ཐ་དད་པ+གཉགས_སྐུལ་ཚིག_ཐ་དད་པ']
# གཅོལ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཉག ['བྱ་ཚིག:གཉོག_མ་འོངས་པ།_###+གཉོགས_མ་འོངས་པ།_###']
# གཉགས ['བྱ་ཚིག:གཉོགས_འདས་པ།_###+གཉོག_འདས་པ།_###']
# གཉིད ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཉིལ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཉུལ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཉེར ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཉེལ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཉོག ['བྱ་ཚིག:གཉོག_མ་འོངས་པ།_ཐ་དད་པ+གཉོགས_ད་ལྟ་བ།_###+གཉོག_ད་ལྟ་བ།_ཐ་དད་པ+གཉོགས_ད་ལྟ་བ།_ཐ་དད་པ+གཉོག_ད་ལྟ་བ།_###+གཉོགས_མ་འོངས་པ།_ཐ་དད་པ']
# གཉོགས ['བྱ་ཚིག:གཉོགས_འདས་པ།_ཐ་དད་པ+གཉོགས_སྐུལ་ཚིག_###+གཉོགས_སྐུལ་ཚིག_ཐ་དད་པ+གཉོག_སྐུལ་ཚིག_###+གཉོག_འདས་པ།_ཐ་དད་པ+གཉོག_སྐུལ་ཚིག_ཐ་དད་པ']
# གཉོད ['བྱ་ཚིག:གཉོད_ད་ལྟ་བ།_ཐ་དད་པ+གཉོད_སྐུལ་ཚིག_ཐ་དད་པ']
# གཏག ['བྱ་ཚིག:གཏག_མ་འོངས་པ།_###+གཏགས_མ་འོངས་པ།_ཐ་དད་པ+གཏག_མ་འོངས་པ།_ཐ་དད་པ+གཏག_ད་ལྟ་བ།_###+གཏག_ད་ལྟ་བ།_ཐ་དད་པ+གཏགས_ད་ལྟ་བ།_ཐ་དད་པ']
# གཏགས ['བྱ་ཚིག:གཏག_འདས་པ།_ཐ་དད་པ+གཏག_འདས་པ།_###+གཏགས_འདས་པ།_ཐ་དད་པ']
# གཏང ['བྱ་ཚིག:བཏང_མ་འོངས་པ།_ཐ་དད་པ+གཏོང_མ་འོངས་པ།_ཐ་དད་པ+གཏོང_མ་འོངས་པ།_###+གཏང_མ་འོངས་པ།_ཐ་དད་པ+ཐོང_མ་འོངས་པ།_ཐ་དད་པ']
# གཏན ['བྱ་ཚིག:གཏོན_འདས་པ།_ཐ་དད་པ+གཏོན_ད་ལྟ་བ།_ཐ་དད་པ+གཏན_མ་འོངས་པ།_ཐ་དད་པ+གཏན_འདས་པ།_ཐ་དད་པ+གཏན_ད་ལྟ་བ།_ཐ་དད་པ+གཏོན_མ་འོངས་པ།_ཐ་དད་པ']
# གཏམས ['བྱ་ཚིག:གཏམས_འདས་པ།_ཐ་དད་པ+གཏམས_མ་འོངས་པ།_ཐ་དད་པ+གཏམས_མ་འོངས་པ།_###+གཏོམས_མ་འོངས་པ།_ཐ་དད་པ+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ+གཏོམས_ད་ལྟ་བ།_ཐ་དད་པ+གཏམས_ད་ལྟ་བ།_ཐ་དད་པ+གཏམས_ད་ལྟ་བ།_###+གཏམས_འདས་པ།_###+གཏོམས_འདས་པ།_ཐ་དད་པ']
# གཏའ ['བྱ་ཚིག:གཏའ_མ་འོངས་པ།_ཐ་དད་པ+གཏས_ད་ལྟ་བ།_ཐ་དད་པ+གཏས_མ་འོངས་པ།_ཐ་དད་པ+གཏའ_ད་ལྟ་བ།_ཐ་དད་པ']
# གཏར ['བྱ་ཚིག:གཏར_ད་ལྟ་བ།_ཐ་དད་པ+གཏོར_འདས་པ།_###+གཏར_འདས་པ།_ཐ་དད་པ+གཏར_མ་འོངས་པ།_ཐ་དད་པ+གཏོར_མ་འོངས་པ།_###+གཏོར_ད་ལྟ་བ།_###']
# གཏས ['བྱ་ཚིག:གཏའ_སྐུལ་ཚིག_ཐ་དད་པ+གཏས_འདས་པ།_ཐ་དད་པ+གཏས_སྐུལ་ཚིག_ཐ་དད་པ+གཏའ_འདས།_ཐ་དད་པ']
# གཏི ['བྱ་ཚིག:བྱ་ཚིག_ཐ་དད་པ']
# གཏིག ['བྱ་ཚིག:གཏིག_ད་ལྟ་བ།_ཐ་དད་པ+བཏིག_ད་ལྟ་བ།_ཐ་དད་པ+གཏིགས_ད་ལྟ་བ།_ཐ་དད་པ+བཏིགས_ད་ལྟ་བ།_ཐ་དད་པ']
# གཏིགས ['བྱ་ཚིག:བཏིགས_སྐུལ་ཚིག_ཐ་དད་པ+གཏིགས_སྐུལ་ཚིག_ཐ་དད་པ+བཏིག_སྐུལ་ཚིག_ཐ་དད་པ+གཏིག_སྐུལ་ཚིག_ཐ་དད་པ']
# གཏིབ ['བྱ་ཚིག:གཏིབ_མ་འོངས་པ།_ཐ་དད་པ+གཏིབ_ད་ལྟ་བ།_ཐ་དད་པ+གཏིབས_ད་ལྟ་བ།_ཐ་དད་པ+གཏིབས_མ་འོངས་པ།_ཐ་དད་པ']
# གཏིབས ['བྱ་ཚིག:གཏིབས_སྐུལ་ཚིག_ཐ་དད་པ+གཏིབ_སྐུལ་ཚིག_ཐ་དད་པ+གཏིབས_འདས་པ།_ཐ་དད་པ+གཏིབ_འདས་པ།_ཐ་དད་པ']
# གཏིམ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཏུག ['བྱ་ཚིག:གཏུག_ད་ལྟ་བ།_ཐ་དད་པ+གཏུག_མ་འོངས་པ།_###+གཏུགས_ད་ལྟ་བ།_ཐ་དད་པ+གཏུགས_མ་འོངས་པ།_ཐ་དད་པ+གཏུག_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཏུག_མ་འོངས་པ།_ཐ་དད་པ+གཏུག_མ་འོངས་པ།_ཐ་མི་དད་པ+གཏུག_ད་ལྟ་བ།_###']
# གཏུགས ['བྱ་ཚིག:གཏུག_སྐུལ་ཚིག_###+གཏུག_སྐུལ་ཚིག_ཐ་དད་པ+གཏུག_སྐུལ་ཚིག_ཐ་མི་དད་པ+གཏུག_འདས་པ།_###+གཏུགས_སྐུལ་ཚིག_ཐ་དད་པ+གཏུག_འདས་པ།_ཐ་མི་དད་པ+གཏུགས_འདས་པ།_ཐ་དད་པ+གཏུག_འདས་པ།_ཐ་དད་པ']
# གཏུབ ['བྱ་ཚིག:གཏུབ_མ་འོངས་པ།_ཐ་དད་པ+གཏུབ_ད་ལྟ་བ།_ཐ་དད་པ+གཏུབས_ད་ལྟ་བ།_ཐ་དད་པ+གཏུབས_མ་འོངས་པ།_ཐ་དད་པ']
# གཏུབས ['བྱ་ཚིག:གཏུབ_སྐུལ་ཚིག_ཐ་དད་པ+གཏུབ_འདས་པ།_ཐ་དད་པ+གཏུབས_འདས་པ།_ཐ་དད་པ+གཏུབས_སྐུལ་ཚིག_ཐ་དད་པ']
# གཏུམ ['བྱ་ཚིག:བཏུམ_མ་འོངས་པ།_ཐ་དད་པ+གཏུམ_མ་འོངས་པ།_ཐ་དད་པ+འཐུམ_མ་འོངས་པ།_ཐ་དད་པ+ཐུམ_མ་འོངས་པ།_ཐ་དད་པ+ཐུམས_མ་འོངས་པ།_ཐ་དད་པ']
# གཏུལ ['བྱ་ཚིག:ཐུལ_མ་འོངས་པ།_###+བཏུལ_མ་འོངས་པ།_###+གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཏོག ['བྱ་ཚིག:གཏོག_ད་ལྟ་བ།_###+གཏོགས_ད་ལྟ་བ།_ཐ་དད་པ+གཏོགས_མ་འོངས་པ།_ཐ་དད་པ+གཏོག_མ་འོངས་པ།_ཐ་དད་པ+གཏོག_ད་ལྟ་བ།_ཐ་དད་པ+གཏོག_མ་འོངས་པ།_###']
# གཏོགས ['བྱ་ཚིག:གཏོག_འདས་པ།_ཐ་དད་པ+གཏོག_སྐུལ་ཚིག_ཐ་དད་པ+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ+གཏོགས_འདས་པ།_ཐ་དད་པ+གཏོག_འདས་པ།_###+གཏོག_སྐུལ་ཚིག_###+གཏགས_སྐུལ་ཚིག_ཐ་དད་པ+གཏག_སྐུལ་ཚིག_ཐ་དད་པ+གཏོགས_སྐུལ་ཚིག_ཐ་དད་པ+གཏག_སྐུལ་ཚིག_###']
# གཏོང ['བྱ་ཚིག:གཏང_ད་ལྟ་བ།_ཐ་དད་པ+བཏང_ད་ལྟ་བ།_ཐ་དད་པ+གཏོང_ད་ལྟ་བ།_ཐ་དད་པ+ཐོང_ད་ལྟ་བ།_ཐ་དད་པ+གཏོང_ད་ལྟ་བ།_###']
# གཏོད ['བྱ་ཚིག:གཏོད_སྐུལ་ཚིག_###+བཏོད_མ་འོངས་པ།_ཐ་དད་པ+གཏོད_སྐུལ་ཚིག_ཐ་དད་པ+འདོད_མ་འོངས་པ།_###+གཏོད_མ་འོངས་པ།_###+གཏོད_ད་ལྟ་བ།_###']
# གཏོན ['བྱ་ཚིག:གཏན_སྐུལ་ཚིག_ཐ་དད་པ+གཏོན_སྐུལ་ཚིག_ཐ་དད་པ']
# གཏོམས ['བྱ་ཚིག:གཏོམས_སྐུལ་ཚིག_ཐ་དད་པ+གཏམས_སྐུལ་ཚིག_###+གཏམས_སྐུལ་ཚིག_ཐ་དད་པ']
# གཏོར ['བྱ་ཚིག:བྱ་ཚིག_###+གཏོར_སྐུལ་ཚིག_###+གཏར_སྐུལ་ཚིག_ཐ་དད་པ+གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གདགས ['བྱ་ཚིག:གདགས_མ་འོངས་པ།_ཐ་དད་པ+བཏགས_མ་འོངས་པ།_ཐ་དད་པ+ཐོགས_མ་འོངས་པ།_ཐ་དད་པ+འདོགས_མ་འོངས་པ།_###+འདོགས_མ་འོངས་པ།_ཐ་དད་པ']
# གདང ['བྱ་ཚིག:གདང_མ་འོངས་པ།_ཐ་དད་པ+གདངས_མ་འོངས་པ།_ཐ་དད་པ+གདང_ད་ལྟ་བ།_ཐ་དད་པ+གདོངས_ད་ལྟ་བ།_ཐ་དད་པ+གདངས_ད་ལྟ་བ།_ཐ་དད་པ+གདོངས_མ་འོངས་པ།_ཐ་དད་པ']
# གདངས ['བྱ་ཚིག:གདངས_འདས་པ།_ཐ་དད་པ+གདོངས_འདས་པ།_ཐ་དད་པ+གདང_འདས་པ།_ཐ་དད་པ+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གདབ ['བྱ་ཚིག:ཐོམས_མ་འོངས་པ།_ཐ་དད་པ+ཐོམ_མ་འོངས་པ།_ཐ་དད་པ+གདབ_མ་འོངས་པ།_ཐ་དད་པ+བཏབ_མ་འོངས་པ།_ཐ་དད་པ+འདེབས_མ་འོངས་པ།_###+ཐོབ_མ་འོངས་པ།_###+འདེབས_མ་འོངས་པ།_ཐ་དད་པ']
# གདམ ['བྱ་ཚིག:བདམ_མ་འོངས་པ།_ཐ་དད་པ+འདོམ_མ་འོངས་པ།_ཐ་དད་པ+གདམ_མ་འོངས་པ།_ཐ་དད་པ+འདེམ_མ་འོངས་པ།_ཐ་དད་པ']
# གདམས ['བྱ་ཚིག:གདམས_འདས་པ།_ཐ་དད་པ+འདོམས_མ་འོངས་པ།_ཐ་དད་པ+གདམས_མ་འོངས་པ།_ཐ་དད་པ+འདོམས_འདས་པ།_ཐ་དད་པ']
# གདལ ['བྱ་ཚིག:གདོལ_ད་ལྟ་བ།_ཐ་དད་པ+བདལ_ད་ལྟ་བ།_ཐ་དད་པ+གདལ_ད་ལྟ་བ།_ཐ་དད་པ+གདལ_ད་ལྟ་བ།_###+བདོལ_ད་ལྟ་བ།_ཐ་དད་པ']
# གདས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གདིང ['བྱ་ཚིག:གདིང_མ་འོངས་པ།_ཐ་དད་པ+བཏིངས_མ་འོངས་པ།_ཐ་དད་པ']
# གདུ ['བྱ་ཚིག:གདུས_ད་ལྟ་བ།_ཐ་དད་པ+གདུ_ད་ལྟ་བ།_ཐ་དད་པ+གདུས_མ་འོངས་པ།_ཐ་དད་པ+གདུ_མ་འོངས་པ།_ཐ་དད་པ']
# གདུག ['བྱ་ཚིག:གདུག_ད་ལྟ་བ།_ཐ་དད་པ+བདུགས_ད་ལྟ་བ།_ཐ་དད་པ+དུགས_མ་འོངས་པ།_ཐ་དད་པ+བདུག_ད་ལྟ་བ།_ཐ་དད་པ+དུགས_ད་ལྟ་བ།_ཐ་དད་པ']
# གདུང ['བྱ་ཚིག:གདུང_མ་འོངས་པ།_ཐ་མི་དད་པ+གདུངས_མ་འོངས་པ།_ཐ་མི་དད་པ+གདུང_མ་འོངས་པ།_###+གདུང_ད་ལྟ་བ།_ཐ་མི་དད་པ+གདུང_ད་ལྟ་བ།_###+གདུངས_ད་ལྟ་བ།_ཐ་མི་དད་པ']
# གདུངས ['བྱ་ཚིག:གདུང_འདས་པ།_ཐ་མི་དད་པ+གདུངས_འདས་པ།_ཐ་མི་དད་པ+གདུང_འདས་པ།_###']
# གདུད ['བྱ་ཚིག:འདུད_མ་འོངས་པ།_ཐ་དད་པ+བཏུད_མ་འོངས་པ།_ཐ་དད་པ+གདུད_མ་འོངས་པ།_ཐ་དད་པ']
# གདུལ ['བྱ་ཚིག:འདུལ_མ་འོངས་པ།_###+བཏུལ_མ་འོངས་པ།_ཐ་དད་པ+ཐུལ_མ་འོངས་པ།_ཐ་དད་པ+འདུལ_མ་འོངས་པ།_ཐ་དད་པ+གདུལ_མ་འོངས་པ།_ཐ་དད་པ']
# གདུས ['བྱ་ཚིག:གདུ_འདས་པ།_ཐ་དད་པ+གདུ_སྐུལ་ཚིག_ཐ་དད་པ+གདུས_སྐུལ་ཚིག_ཐ་དད་པ+གདུས_འདས་པ།_ཐ་དད་པ']
# གདེག ['བྱ་ཚིག:བཏེག_མ་འོངས་པ།_ཐ་དད་པ+འདེགས_མ་འོངས་པ།_ཐ་དད་པ+གདེག_མ་འོངས་པ།_ཐ་དད་པ']
# གདེང ['བྱ་ཚིག:གདེང_མ་འོངས་པ།_ཐ་དད་པ+གདེང_ད་ལྟ་བ།_ཐ་དད་པ+གདེངས_མ་འོངས་པ།_ཐ་དད་པ+གདེངས_ད་ལྟ་བ།_ཐ་དད་པ']
# གདེངས ['བྱ་ཚིག:གདེངས_འདས་པ།_ཐ་དད་པ+གདེང_སྐུལ་ཚིག_ཐ་དད་པ+གདེངས_སྐུལ་ཚིག_ཐ་དད་པ+གདེང_འདས་པ།_ཐ་དད་པ']
# གདོངས ['བྱ་ཚིག:གདོངས_སྐུལ་ཚིག_ཐ་དད་པ+གདང_སྐུལ་ཚིག_ཐ་དད་པ+གདངས_སྐུལ་ཚིག_ཐ་དད་པ']
# གདོད ['བྱ་ཚིག:ཐོད_མ་འོངས་པ།_ཐ་དད་པ+བྱ་ཚིག_ཐ་དད་པ']
# གདོན ['བྱ་ཚིག:བཏོན_མ་འོངས་པ།_ཐ་དད་པ+འདོན_མ་འོངས་པ།_ཐ་དད་པ+འདོན_མ་འོངས་པ།_###+ཐོན_མ་འོངས་པ།_ཐ་དད་པ+གདོམས_མ་འོངས་པ།_ཐ་དད་པ+གདོན_མ་འོངས་པ།_ཐ་དད་པ']
# གདོམས ['བྱ་ཚིག:བདམ_སྐུལ་ཚིག_ཐ་དད་པ+འདོམ_སྐུལ་ཚིག_ཐ་དད་པ+འདེམ_སྐུལ་ཚིག_ཐ་དད་པ+གདམ_སྐུལ་ཚིག_ཐ་དད་པ+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གདོལ ['བྱ་ཚིག:གདལ_སྐུལ་ཚིག_###+གདོལ_སྐུལ་ཚིག_ཐ་དད་པ+གདལ_སྐུལ་ཚིག_ཐ་དད་པ']
# གནག ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གནང ['བྱ་ཚིག:གནོངས_འདས་པ།_ཐ་དད་པ+གནོངས_ད་ལྟ་བ།_ཐ་དད་པ+གནང_མ་འོངས་པ།_ཐ་དད་པ+གནང_ད་ལྟ་བ།_ཐ་དད་པ+གནོངས_མ་འོངས་པ།_ཐ་དད་པ+གནང_འདས་པ།_ཐ་དད་པ']
# གནན ['བྱ་ཚིག:གནན_མ་འོངས་པ།_ཐ་དད་པ']
# གནར ['བྱ་ཚིག:གནར_ད་ལྟ་བ།_###+གནར_མ་འོངས་པ།_###+གནར_ད་ལྟ་བ།_ཐ་མི་དད་པ+གནར_མ་འོངས་པ།_ཐ་མི་དད་པ+གནར_འདས་པ།_###+གནར_འདས་པ།_ཐ་མི་དད་པ']
# གནས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གནོང ['བྱ་ཚིག:གནོང_ད་ལྟ་བ།_ཐ་དད་པ+གནོངས_ད་ལྟ་བ།_###+གནོང_མ་འོངས་པ།_ཐ་མི་དད་པ+གནོང_ད་ལྟ་བ།_ཐ་མི་དད་པ+གནོང_མ་འོངས་པ།_ཐ་དད་པ+གནོངས_ད་ལྟ་བ།_ཐ་མི་དད་པ+གནོངས_མ་འོངས་པ།_###+གནོངས_མ་འོངས་པ།_ཐ་མི་དད་པ']
# གནོངས ['བྱ་ཚིག:གནོངས_འདས་པ།_###+གནོང_སྐུལ་ཚིག_ཐ་དད་པ+གནོངས_སྐུལ་ཚིག_###+གནོངས_འདས་པ།_ཐ་མི་དད་པ+གནོང_འདས་པ།_ཐ་མི་དད་པ+གནོངས_སྐུལ་ཚིག_ཐ་དད་པ+གནོང_འདས་པ།_ཐ་དད་པ+གནང_སྐུལ་ཚིག_ཐ་དད་པ']
# གནོད ['བྱ་ཚིག:བྱ་ཚིག_###+གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གནོན ['བྱ་ཚིག:མནན_ད་ལྟ་བ།_ཐ་དད་པ+གནན_ད་ལྟ་བ།_ཐ་དད་པ+གནོན_ད་ལྟ་བ།_ཐ་དད་པ+ནོན_ད་ལྟ་བ།_ཐ་དད་པ']
# གནོས ['བྱ་ཚིག:མནོས_སྐུལ་ཚིག_ཐ་དད་པ+གནོས_སྐུལ་ཚིག_ཐ་དད་པ+མནོད_སྐུལ་ཚིག_ཐ་དད་པ+ནོད_སྐུལ་ཚིག_ཐ་དད་པ']
# གབ ['བྱ་ཚིག:གབ_ད་ལྟ་བ།_ཐ་དད་པ+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ+གོབ_མ་འོངས་པ།_ཐ་དད་པ+གོབ_འདས་པ།_ཐ་དད་པ+གོབ_ད་ལྟ་བ།_ཐ་དད་པ+གབ_འདས་པ།_ཐ་དད་པ+གབ_མ་འོངས་པ།_ཐ་དད་པ']
# གཙག ['བྱ་ཚིག:གཙག_ད་ལྟ་བ།_ཐ་དད་པ+གཙོགས_ད་ལྟ་བ།_ཐ་དད་པ+གཙག_མ་འོངས་པ།_###+ཚོག_མ་འོངས་པ།_ཐ་དད་པ+གཙག_ད་ལྟ་བ།_###+གཙགས_མ་འོངས་པ།_ཐ་དད་པ+གཙགས_ད་ལྟ་བ།_ཐ་དད་པ+གཙག_མ་འོངས་པ།_ཐ་དད་པ+གཙོགས_མ་འོངས་པ།_ཐ་དད་པ+འཚག_མ་འོངས་པ།_ཐ་དད་པ']
# གཙགས ['བྱ་ཚིག:གཙག_འདས་པ།_###+གཙག_འདས་པ།_ཐ་དད་པ+གཙོགས_འདས་པ།_ཐ་དད་པ+གཙགས_འདས་པ།_ཐ་དད་པ']
# གཙབ ['བྱ་ཚིག:གཙབས_ད་ལྟ་བ།_ཐ་དད་པ+གཙབ_མ་འོངས་པ།_ཐ་དད་པ+གཙོབས_ད་ལྟ་བ།_ཐ་དད་པ+གཙབས_མ་འོངས་པ།_ཐ་དད་པ+གཙབ_ད་ལྟ་བ།_ཐ་དད་པ+གཙོབས_མ་འོངས་པ།_ཐ་དད་པ']
# གཙབས ['བྱ་ཚིག:གཙོབས_འདས་པ།_ཐ་དད་པ+གཙབ_འདས་པ།_ཐ་དད་པ+གཙབས_འདས་པ།_ཐ་དད་པ']
# གཙི ['བྱ་ཚིག:གཙི_མ་འོངས་པ།_ཐ་དད་པ+བྱ་ཚིག_###+གཙིས_ད་ལྟ་བ།_ཐ་དད་པ+གཙི_ད་ལྟ་བ།_ཐ་དད་པ+གཙིས_མ་འོངས་པ།_ཐ་དད་པ']
# གཙིག ['བྱ་ཚིག:གཙིག_ད་ལྟ་བ།_ཐ་དད་པ+གཙིགས_མ་འོངས་པ།_ཐ་དད་པ+གཙིག_མ་འོངས་པ།_ཐ་དད་པ+གཙིགས_ད་ལྟ་བ།_ཐ་དད་པ']
# གཙིགས ['བྱ་ཚིག:གཙིག_སྐུལ་ཚིག_ཐ་དད་པ+གཙིགས_འདས་པ།_ཐ་དད་པ+གཙིགས_སྐུལ་ཚིག_ཐ་དད་པ+གཙིག_འདས་པ།_ཐ་དད་པ']
# གཙིར ['བྱ་ཚིག:བྱ་ཚིག_ཐ་དད་པ']
# གཙིས ['བྱ་ཚིག:གཙི_སྐུལ་ཚིག_ཐ་དད་པ+གཙིས_སྐུལ་ཚིག_ཐ་དད་པ+གཙི_འདས་པ།_ཐ་དད་པ+གཙིས_འདས་པ།_ཐ་དད་པ']
# གཙུབ ['བྱ་ཚིག:གཙུབ_མ་འོངས་པ།_###+གཙུབ_མ་འོངས་པ།_ཐ་དད་པ+གཙུབ_ད་ལྟ་བ།_ཐ་དད་པ+གཙུབས_མ་འོངས་པ།_ཐ་དད་པ+གཙུབས_ད་ལྟ་བ།_ཐ་དད་པ+གཙུབ_ད་ལྟ་བ།_###']
# གཙུབས ['བྱ་ཚིག:གཙུབས_སྐུལ་ཚིག_ཐ་དད་པ+གཙུབ_སྐུལ་ཚིག_###+གཙུབ_སྐུལ་ཚིག_ཐ་དད་པ+གཙུབ_འདས་པ།_###+གཙུབས_འདས་པ།_ཐ་དད་པ+གཙུབ_འདས་པ།_ཐ་དད་པ']
# གཙེ ['བྱ་ཚིག:གཙེ_ད་ལྟ་བ།_ཐ་དད་པ+གཙེས_མ་འོངས་པ།_ཐ་དད་པ+གཙོག_ད་ལྟ་བ།_ཐ་དད་པ+གཙོག_མ་འོངས་པ།_ཐ་དད་པ+གཙེ_མ་འོངས་པ།_ཐ་དད་པ+གཙེས_ད་ལྟ་བ།_ཐ་དད་པ']
# གཙེར ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཙེས ['བྱ་ཚིག:གཙེས_སྐུལ་ཚིག_ཐ་དད་པ+གཙོག_སྐུལ་ཚིག_ཐ་དད་པ+གཙེ_སྐུལ་ཚིག_ཐ་དད་པ+གཙེས_འདས་པ།_ཐ་དད་པ+གཙེ_འདས་པ།_ཐ་དད་པ+གཙོག_འདས་པ།_ཐ་དད་པ']
# གཙོག ['བྱ་ཚིག:བཙོག_མ་འོངས་པ།_ཐ་དད་པ+ཚོག_མ་འོངས་པ།_###+འཚོག_མ་འོངས་པ།_ཐ་དད་པ']
# གཙོགས ['བྱ་ཚིག:གཙག_སྐུལ་ཚིག_ཐ་དད་པ+གཙགས_སྐུལ་ཚིག_ཐ་དད་པ+གཙག_སྐུལ་ཚིག_###+གཙོགས_སྐུལ་ཚིག_ཐ་དད་པ']
# གཙོབས ['བྱ་ཚིག:གཙབ_སྐུལ་ཚིག_ཐ་དད་པ+གཙབས_སྐུལ་ཚིག_ཐ་དད་པ+གཙོབས_སྐུལ་ཚིག_ཐ་དད་པ']
# གཞག ['བྱ་ཚིག:ཞོག_མ་འོངས་པ།_ཐ་དད་པ+འཇོག_མ་འོངས་པ།_###+བཞག_མ་འོངས་པ།_ཐ་དད་པ+གཞག_མ་འོངས་པ།_ཐ་དད་པ+འཇོག_མ་འོངས་པ།_ཐ་དད་པ']
# གཞབ ['བྱ་ཚིག:བཞབ_ད་ལྟ་བ།_ཐ་དད་པ+འཇབ_མ་འོངས་པ།_ཐ་དད་པ+བཞབ_མ་འོངས་པ།_###+གཞབ_མ་འོངས་པ།_###+གཞབ_ད་ལྟ་བ།_###+འཇོབ_མ་འོངས་པ།_ཐ་དད་པ']
# གཞའ ['བྱ་ཚིག:བྱ་ཚིག_###+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཞར ['བྱ་ཚིག:བཞར_ད་ལྟ་བ།_ཐ་དད་པ+གཞར_ད་ལྟ་བ།_###+བཞོར_ད་ལྟ་བ།_ཐ་དད་པ+གཞར_ད་ལྟ་བ།_ཐ་དད་པ']
# གཞལ ['བྱ་ཚིག:འཇལ_མ་འོངས་པ།_ཐ་དད་པ+འཇོལ_མ་འོངས་པ།_ཐ་དད་པ+བཅལ_མ་འོངས་པ།_ཐ་དད་པ+འཇལ_མ་འོངས་པ།_###+འཇོས_མ་འོངས་པ།_ཐ་དད་པ+གཞལ_མ་འོངས་པ།_ཐ་དད་པ']
# གཞིག ['བྱ་ཚིག:གཞིག_ད་ལྟ་བ།_ཐ་དད་པ+གཞིབ_ད་ལྟ་བ།_ཐ་དད་པ+ཤིག_མ་འོངས་པ།_###+གཞིགས_མ་འོངས་པ།_ཐ་དད་པ+གཞིགས_ད་ལྟ་བ།_ཐ་དད་པ+བཤིག_མ་འོངས་པ།_###+གཞིབ_མ་འོངས་པ།_ཐ་དད་པ+གཞིག_མ་འོངས་པ།_ཐ་དད་པ+ཞིག_མ་འོངས་པ།_ཐ་དད་པ+འཇིག_མ་འོངས་པ།_ཐ་དད་པ']
# གཞིགས ['བྱ་ཚིག:གཞིག_འདས་པ།_ཐ་དད་པ+གཞིབ_འདས་པ།_ཐ་དད་པ+གཞིགས_སྐུལ་ཚིག_ཐ་དད་པ+གཞིབ_སྐུལ་ཚིག_ཐ་དད་པ+གཞིག_སྐུལ་ཚིག_ཐ་དད་པ+གཞིགས_འདས་པ།_ཐ་དད་པ']
# གཞིབ ['བྱ་ཚིག:འཇིབས_མ་འོངས་པ།_ཐ་དད་པ+བཞིབ_མ་འོངས་པ།_ཐ་དད་པ+འཇིབ_མ་འོངས་པ།_ཐ་དད་པ']
# གཞིབས ['བྱ་ཚིག:བྱ་ཚིག_ཐ་དད་པ']
# གཞིལ ['བྱ་ཚིག:བཅིལ_མ་འོངས་པ།_ཐ་དད་པ+འཇིལ_མ་འོངས་པ།_ཐ་དད་པ+གཞིལ_མ་འོངས་པ།_ཐ་དད་པ']
# གཞུ ['བྱ་ཚིག:གཞུ_ད་ལྟ་བ།_ཐ་དད་པ+གཞུས_ད་ལྟ་བ།_ཐ་དད་པ+གཞུས_མ་འོངས་པ།_ཐ་དད་པ+གཞུ_མ་འོངས་པ།_ཐ་དད་པ+གཞུག_མ་འོངས་པ།_ཐ་དད་པ+གཞུག_ད་ལྟ་བ།_ཐ་དད་པ']
# གཞུག ['བྱ་ཚིག:ཆུག_མ་འོངས་པ།_ཐ་དད་པ+བཅུག_མ་འོངས་པ།_ཐ་དད་པ+ཆུགས_མ་འོངས་པ།_ཐ་དད་པ+འཇུག_མ་འོངས་པ།_ཐ་དད་པ']
# གཞུར ['བྱ་ཚིག:བཞུར_སྐུལ་ཚིག_ཐ་དད་པ+གཞུར_མ་འོངས་པ།_ཐ་དད་པ+གཞུར_སྐུལ་ཚིག_ཐ་དད་པ+བཞུར_ད་ལྟ་བ།_ཐ་དད་པ+བཞུར_མ་འོངས་པ།_ཐ་དད་པ+གཞུར_ད་ལྟ་བ།_ཐ་དད་པ']
# གཞུས ['བྱ་ཚིག:གཞུས_སྐུལ་ཚིག_ཐ་དད་པ+གཞུག_འདས་པ།_ཐ་དད་པ+གཞུས_འདས་པ།_ཐ་དད་པ+གཞུ_འདས་པ།_ཐ་དད་པ+གཞུ_སྐུལ་ཚིག_ཐ་དད་པ+གཞུག_སྐུལ་ཚིག_ཐ་དད་པ']
# གཞེན ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཞེར ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཞེས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཞོག ['བྱ་ཚིག:བཞོག_ད་ལྟ་བ།_ཐ་དད་པ+གཞོག_མ་འོངས་པ།_ཐ་དད་པ+བཞོག_མ་འོངས་པ།_ཐ་དད་པ+གཞོག_ད་ལྟ་བ།_ཐ་དད་པ']
# གཞོགས ['བྱ་ཚིག:བྱ་ཚིག_ཐ་དད་པ']
# གཞོབ ['བྱ་ཚིག:གཞོབ_མ་འོངས་པ།_###+གཞོབ_ད་ལྟ་བ།_ཐ་དད་པ+གཞོབ_མ་འོངས་པ།_ཐ་དད་པ+གཞབ_སྐུལ་ཚིག_###+གཞོབས_ད་ལྟ་བ།_ཐ་དད་པ+གཞོབ_ད་ལྟ་བ།_###+གཞོབས_མ་འོངས་པ།_ཐ་དད་པ']
# གཞོབས ['བྱ་ཚིག:གཞོབས_སྐུལ་ཚིག_ཐ་དད་པ+གཞོབ_སྐུལ་ཚིག_###+གཞོབ_སྐུལ་ཚིག_ཐ་དད་པ+གཞོབ_འདས་པ།_ཐ་དད་པ+གཞོབ_འདས་པ།_###+གཞོབས_འདས་པ།_ཐ་དད་པ']
# གཞོམ ['བྱ་ཚིག:འཇོམས_མ་འོངས་པ།_ཐ་དད་པ+གཞོར_མ་འོངས་པ།_ཐ་དད་པ+ཆོམས_མ་འོངས་པ།_ཐ་དད་པ+གཞོམ_མ་འོངས་པ།_ཐ་དད་པ+གཞོས_མ་འོངས་པ།_ཐ་དད་པ+བཅོམ_མ་འོངས་པ།_ཐ་དད་པ+ཆོམ_མ་འོངས་པ།_ཐ་དད་པ']
# གཞོར ['བྱ་ཚིག:གཞར_སྐུལ་ཚིག_###+གཞར_སྐུལ་ཚིག_ཐ་དད་པ+བཞོར_སྐུལ་ཚིག_ཐ་དད་པ+བཞར_སྐུལ་ཚིག_ཐ་དད་པ']
# གཞོལ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_###+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཞོས ['བྱ་ཚིག:འཇོ_སྐུལ་ཚིག_ཐ་དད་པ+བཞོས_སྐུལ་ཚིག_ཐ་དད་པ+བཞོ_སྐུལ་ཚིག_ཐ་དད་པ+ཞོས_སྐུལ་ཚིག_ཐ་དད་པ']
# གཟག ['བྱ་ཚིག:གཟོགས_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཟོགས_མ་འོངས་པ།_ཐ་མི་དད་པ+གཟག_ད་ལྟ་བ།_ཐ་དད་པ+གཟག_མ་འོངས་པ།_ཐ་དད་པ+གཟགས_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཟགས_ད་ལྟ་བ།_ཐ་དད་པ+གཟགས_མ་འོངས་པ།_ཐ་མི་དད་པ+གཟགས_མ་འོངས་པ།_ཐ་དད་པ']
# གཟགས ['བྱ་ཚིག:གཟོགས_འདས་པ།_ཐ་མི་དད་པ+གཟགས_འདས་པ།_ཐ་མི་དད་པ+གཟགས_འདས་པ།_ཐ་དད་པ+གཟག_འདས་པ།_ཐ་དད་པ']
# གཟན ['བྱ་ཚིག:གཟོན_ད་ལྟ་བ།_ཐ་དད་པ+གཟན_འདས་པ།_###+གཟོན_འདས་པ།_ཐ་དད་པ+གཟན_ད་ལྟ་བ།_###+གཟོན_མ་འོངས་པ།_ཐ་དད་པ+གཟན_མ་འོངས་པ།_###+གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཟབ ['བྱ་ཚིག:གཟབ_མ་འོངས་པ།_ཐ་དད་པ+གཟོབས_ད་ལྟ་བ།_ཐ་དད་པ+བཟབས_ད་ལྟ་བ།_ཐ་དད་པ+བཟབ_ད་ལྟ་བ།_ཐ་དད་པ+གཟབ_ད་ལྟ་བ།_ཐ་དད་པ']
# གཟར ['བྱ་ཚིག:གཟོར_ད་ལྟ་བ།_ཐ་དད་པ+བཟར_མ་འོངས་པ།_ཐ་དད་པ+གཟར_ད་ལྟ་བ།_ཐ་དད་པ+འཛར_མ་འོངས་པ།_ཐ་མི་དད་པ+གཟོར_འདས་པ།_ཐ་དད་པ+གཟར_འདས་པ།_ཐ་དད་པ+གཟར_མ་འོངས་པ།_ཐ་དད་པ+བཟར_མ་འོངས་པ།_ཐ་མི་དད་པ+བཟར_འདས་པ།_ཐ་མི་དད་པ+འཛར_མ་འོངས་པ།_ཐ་དད་པ+གཟོར_མ་འོངས་པ།_ཐ་དད་པ+འཛར_འདས་པ།_ཐ་མི་དད་པ']
# གཟས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཟིགས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཟིང ['བྱ་ཚིག:བྱ་ཚིག_ཐ་མི་དད་པ']
# གཟིམ ['བྱ་ཚིག:གཟིམ_མ་འོངས་པ།_ཐ་མི་དད་པ+གཟིམས_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཟིམས_མ་འོངས་པ།_ཐ་མི་དད་པ+གཟིམ_ད་ལྟ་བ།_ཐ་མི་དད་པ']
# གཟིམས ['བྱ་ཚིག:གཟིམ_འདས་པ།_ཐ་མི་དད་པ+གཟིམས_འདས་པ།_ཐ་མི་དད་པ+གཟིམས_སྐུལ་ཚིག_ཐ་མི་དད་པ+གཟིམ_སྐུལ་ཚིག_ཐ་མི་དད་པ']
# གཟིར ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཟུགས ['བྱ་ཚིག:འཛུགས_མ་འོངས་པ།_###+ཚུགས_མ་འོངས་པ།_ཐ་དད་པ+འཛུགས_མ་འོངས་པ།_ཐ་དད་པ+བཙུགས_མ་འོངས་པ།_ཐ་དད་པ+གཟུགས_མ་འོངས་པ།_ཐ་དད་པ']
# གཟུང ['བྱ་ཚིག:བཟུང_མ་འོངས་པ།_ཐ་དད་པ+གཟུང_མ་འོངས་པ།_ཐ་དད་པ+འཛིན_མ་འོངས་པ།_ཐ་དད་པ+ཟུངས_མ་འོངས་པ།_ཐ་དད་པ+ཟུད_མ་འོངས་པ།_ཐ་དད་པ+ཟུང_མ་འོངས་པ།_ཐ་དད་པ+འཛིན_མ་འོངས་པ།_###']
# གཟུད ['བྱ་ཚིག:གཟུད_མ་འོངས་པ།_ཐ་དད་པ+ཚུད_མ་འོངས་པ།_ཐ་དད་པ+བཙུད_མ་འོངས་པ།_ཐ་དད་པ+འཛུད_མ་འོངས་པ།_ཐ་དད་པ']
# གཟུམ ['བྱ་ཚིག:གཟུམ_མ་འོངས་པ།_ཐ་དད་པ']
# གཟུར ['བྱ་ཚིག:འཛུར_མ་འོངས་པ།_ཐ་མི་དད་པ+ཟུར_མ་འོངས་པ།_ཐ་དད་པ+བཟུར_མ་འོངས་པ།_ཐ་མི་དད་པ+གཟུར_མ་འོངས་པ།_ཐ་མི་དད་པ']
# གཟེག ['བྱ་ཚིག:བྱ་ཚིག_ཐ་མི་དད་པ']
# གཟེང ['བྱ་ཚིག:གཟེང_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཟེང_མ་འོངས་པ།_ཐ་མི་དད་པ+གཟེངས_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཟེངས_མ་འོངས་པ།_ཐ་མི་དད་པ']
# གཟེངས ['བྱ་ཚིག:གཟེང_འདས་པ།_ཐ་མི་དད་པ+གཟེངས_འདས་པ།_ཐ་མི་དད་པ']
# གཟེད ['བྱ་ཚིག:གཟེད_མ་འོངས་པ།_ཐ་མི་དད་པ+བཟེད_མ་འོངས་པ།_ཐ་དད་པ+ཟེད_མ་འོངས་པ།_ཐ་དད་པ+འཛེད_མ་འོངས་པ།_ཐ་དད་པ']
# གཟེམ ['བྱ་ཚིག:བྱ་ཚིག_ཐ་དད་པ']
# གཟེར ['བྱ་ཚིག:འཛར_སྐུལ་ཚིག_ཐ་དད་པ+བཟར_སྐུལ་ཚིག_ཐ་དད་པ+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཟོ ['བྱ་ཚིག:གཟོ_མ་འོངས་པ།_ཐ་དད་པ+གཟོས_ད་ལྟ་བ།_ཐ་དད་པ+གཟོ_ད་ལྟ་བ།_ཐ་དད་པ+གཟོས_མ་འོངས་པ།_ཐ་དད་པ']
# གཟོགས ['བྱ་ཚིག:གཟགས_སྐུལ་ཚིག_ཐ་དད་པ+གཟག_སྐུལ་ཚིག_ཐ་དད་པ+གཟོགས_སྐུལ་ཚིག_ཐ་མི་དད་པ']
# གཟོན ['བྱ་ཚིག:གཟན_སྐུལ་ཚིག_###+གཟོན_སྐུལ་ཚིག_ཐ་དད་པ']
# གཟོབ ['བྱ་ཚིག:བྱ་ཚིག_ཐ་དད་པ']
# གཟོབས ['བྱ་ཚིག:བཟབས_སྐུལ་ཚིག_ཐ་དད་པ+བཟབ_སྐུལ་ཚིག_ཐ་དད་པ+གཟབ_སྐུལ་ཚིག_ཐ་དད་པ+གཟོབས_སྐུལ་ཚིག_ཐ་དད་པ']
# གཟོར ['བྱ་ཚིག:གཟོར_སྐུལ་ཚིག_ཐ་དད་པ+གཟར_སྐུལ་ཚིག_ཐ་དད་པ']
# གཟོས ['བྱ་ཚིག:གཟོས_སྐུལ་ཚིག_ཐ་དད་པ+གཟོ_འདས་པ།_ཐ་དད་པ+གཟོ_སྐུལ་ཚིག_ཐ་དད་པ+གཟོས_འདས་པ།_ཐ་དད་པ']
# གཡབ ['བྱ་ཚིག:གཡོབ_མ་འོངས་པ།_ཐ་དད་པ+གཡབ_མ་འོངས་པ།_ཐ་དད་པ+གཡབས_མ་འོངས་པ།_ཐ་དད་པ+གཡོབ_མ་འོངས་པ།_###+གཡོབས_མ་འོངས་པ།_ཐ་དད་པ']
# གཡབས ['བྱ་ཚིག:གཡབས_འདས་པ།_ཐ་དད་པ+གཡོབས_འདས་པ།_ཐ་དད་པ+གཡབ_འདས་པ།_ཐ་དད་པ+གཡོབ_འདས་པ།_ཐ་དད་པ+གཡོབ_འདས་པ།_###']
# གཡར ['བྱ་ཚིག:གཡོར_འདས་པ།_ཐ་དད་པ+གཡར_མ་འོངས་པ།_ཐ་དད་པ+གཡར_ད་ལྟ་བ།_ཐ་དད་པ+གཡོར_ད་ལྟ་བ།_ཐ་དད་པ+གཡར_འདས་པ།_ཐ་དད་པ+གཡོར_མ་འོངས་པ།_ཐ་དད་པ']
# གཡལ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཡིག ['བྱ་ཚིག:གཡིག_མ་འོངས་པ།_ཐ་མི་དད་པ+གཡིག_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཡིགས_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཡིགས_མ་འོངས་པ།_ཐ་མི་དད་པ']
# གཡིགས ['བྱ་ཚིག:གཡིག_འདས་པ།_ཐ་མི་དད་པ+གཡིགས_འདས་པ།_ཐ་མི་དད་པ']
# གཡུག ['བྱ་ཚིག:གཡུག_མ་འོངས་པ།_ཐ་དད་པ+གཡུག_ད་ལྟ་བ།_###+གཡུགས_ད་ལྟ་བ།_ཐ་དད་པ+གཡུག_མ་འོངས་པ།_###+གཡུག_ད་ལྟ་བ།_ཐ་དད་པ+གཡུགས_མ་འོངས་པ།_ཐ་དད་པ']
# གཡུགས ['བྱ་ཚིག:གཡུག_འདས་པ།_###+གཡུག_འདས་པ།_ཐ་དད་པ+གཡུགས_འདས་པ།_ཐ་དད་པ+གཡུག_སྐུལ་ཚིག_ཐ་དད་པ+གཡུགས_སྐུལ་ཚིག_ཐ་དད་པ+གཡུག_སྐུལ་ཚིག_###']
# གཡུར ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཡེང ['བྱ་ཚིག:གཡེང_ད་ལྟ་བ།_ཐ་དད་པ+གཡེང_མ་འོངས་པ།_###+གཡེངས_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཡེངས_ད་ལྟ་བ།_ཐ་དད་པ+གཡེངས_མ་འོངས་པ།_ཐ་དད་པ+གཡེང_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཡེང_མ་འོངས་པ།_ཐ་དད་པ+གཡེངས_མ་འོངས་པ།_ཐ་མི་དད་པ+གཡེང_མ་འོངས་པ།_ཐ་མི་དད་པ+གཡེང_ད་ལྟ་བ།_###']
# གཡེངས ['བྱ་ཚིག:གཡེངས_སྐུལ་ཚིག_ཐ་དད་པ+གཡེངས_འདས་པ།_ཐ་མི་དད་པ+གཡེང_འདས་པ།_ཐ་དད་པ+གཡེངས_འདས་པ།_ཐ་དད་པ+གཡེང_འདས་པ།_###+གཡེང_འདས་པ།_ཐ་མི་དད་པ+གཡེང_སྐུལ་ཚིག_ཐ་དད་པ']
# གཡེམ ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཡེལ ['བྱ་ཚིག:བྱ་ཚིག_###+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཡོ ['བྱ་ཚིག:གཡོས_མ་འོངས་པ།_ཐ་མི་དད་པ+གཡོས_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཡོ_མ་འོངས་པ།_ཐ་དད་པ+གཡོས_ད་ལྟ་བ།_ཐ་དད་པ+གཡོ_ད་ལྟ་བ།_ཐ་དད་པ+གཡོ_ད་ལྟ་བ།_ཐ་མི་དད་པ+གཡོ_མ་འོངས་པ།_ཐ་མི་དད་པ+གཡོས_མ་འོངས་པ།_ཐ་དད་པ']
# གཡོག ['བྱ་ཚིག:གཡོགས_ད་ལྟ་བ།_ཐ་དད་པ+གཡོགས_མ་འོངས་པ།_ཐ་དད་པ+གཡོག_ད་ལྟ་བ།_###+གཡོག_མ་འོངས་པ།_###+གཡོག_ད་ལྟ་བ།_ཐ་དད་པ+གཡོག_མ་འོངས་པ།_ཐ་དད་པ']
# གཡོགས ['བྱ་ཚིག:གཡོག_སྐུལ་ཚིག_###+གཡོགས_འདས་པ།_ཐ་དད་པ+གཡོག_འདས་པ།_ཐ་དད་པ+གཡོག_སྐུལ་ཚིག_ཐ་དད་པ+གཡོག_འདས་པ།_###+གཡོགས_སྐུལ་ཚིག_ཐ་དད་པ']
# གཡོབ ['བྱ་ཚིག:གཡབས_ད་ལྟ་བ།_ཐ་དད་པ+གཡོབ_ད་ལྟ་བ།_###+གཡབ_ད་ལྟ་བ།_ཐ་དད་པ+གཡོབ_ད་ལྟ་བ།_ཐ་དད་པ+གཡོབས_ད་ལྟ་བ།_ཐ་དད་པ']
# གཡོབས ['བྱ་ཚིག:གཡོབ_སྐུལ་ཚིག_ཐ་དད་པ+གཡབས_སྐུལ་ཚིག_ཐ་དད་པ+གཡོབ_སྐུལ་ཚིག_###+གཡོབས_སྐུལ་ཚིག_ཐ་དད་པ+གཡབ_སྐུལ་ཚིག_ཐ་དད་པ']
# གཡོར ['བྱ་ཚིག:གཡར_སྐུལ་ཚིག_ཐ་དད་པ+གཡོར_སྐུལ་ཚིག_ཐ་དད་པ']
# གཡོས ['བྱ་ཚིག:གཡོས_སྐུལ་ཚིག_ཐ་དད་པ+གཡོ_འདས་པ།_ཐ་མི་དད་པ+གཡོས_འདས་པ།_ཐ་མི་དད་པ+གཡོ_སྐུལ་ཚིག_ཐ་མི་དད་པ+གཡོ_སྐུལ་ཚིག_ཐ་དད་པ+གཡོ_འདས་པ།_ཐ་དད་པ+གཡོས_འདས་པ།_ཐ་དད་པ+གཡོས_སྐུལ་ཚིག_ཐ་མི་དད་པ']
# གཤག ['བྱ་ཚིག:གཤོག_མ་འོངས་པ།_ཐ་དད་པ+གཤག_མ་འོངས་པ།_ཐ་དད་པ+གཤགས_མ་འོངས་པ།_ཐ་དད་པ+གཤོགས_མ་འོངས་པ།_ཐ་དད་པ']
# གཤགས ['བྱ་ཚིག:གཤོགས_འདས་པ།_ཐ་དད་པ+བྱ་ཚིག_###+གཤོག_འདས་པ།_ཐ་དད་པ+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ+གཤགས_འདས་པ།_ཐ་དད་པ+གཤག_འདས་པ།_ཐ་དད་པ']
# གཤར ['བྱ་ཚིག:བཤར_ད་ལྟ་བ།_ཐ་དད་པ+བཤར_མ་འོངས་པ།_ཐ་དད་པ+བཤར_མ་འོངས་པ།_###+བཤར_ད་ལྟ་བ།_###+གཤར_མ་འོངས་པ།_ཐ་མི་དད་པ+གཤར_ད་ལྟ་བ།_ཐ་མི་དད་པ']
# གཤལ ['བྱ་ཚིག:བྱ་ཚིག_ཐ་དད་པ']
# གཤིབ ['བྱ་ཚིག:གཤིབ_མ་འོངས་པ།_###+གཤིབས_མ་འོངས་པ།_ཐ་དད་པ+གཤིབ_ད་ལྟ་བ།_ཐ་དད་པ+གཤིབ_མ་འོངས་པ།_ཐ་དད་པ+གཤིབས_ད་ལྟ་བ།_ཐ་དད་པ+གཤིབ_ད་ལྟ་བ།_###']
# གཤིབས ['བྱ་ཚིག:གཤིབ_འདས་པ།_###+གཤིབས_འདས་པ།_ཐ་དད་པ+གཤིབ_སྐུལ་ཚིག_###+གཤིབ_སྐུལ་ཚིག_ཐ་དད་པ+གཤིབ_འདས་པ།_ཐ་དད་པ+གཤིབས_སྐུལ་ཚིག_ཐ་དད་པ']
# གཤུ ['བྱ་ཚིག:གཤུ_ད་ལྟ་བ།_ཐ་དད་པ']
# གཤུང ['བྱ་ཚིག:བཤུངས_ད་ལྟ་བ།_ཐ་དད་པ+ཤུངས_ད་ལྟ་བ།_ཐ་དད་པ+གཤུང_ད་ལྟ་བ།_ཐ་དད་པ+བཤུང_ད་ལྟ་བ།_ཐ་དད་པ']
# གཤུད ['བྱ་ཚིག:གཤུད_ད་ལྟ་བ།_ཐ་དད་པ+གཤུད_མ་འོངས་པ།_ཐ་དད་པ+བཤུད_ད་ལྟ་བ།_###+བཤུད_མ་འོངས་པ།_###']
# གཤུམ ['བྱ་ཚིག:བྱ་ཚིག_ཐ་མི་དད་པ']
# གཤུར ['བྱ་ཚིག:ཤུར_ད་ལྟ་བ།_ཐ་དད་པ+གཤུར_ད་ལྟ་བ།_ཐ་དད་པ+བཤུར_ད་ལྟ་བ།_ཐ་དད་པ']
# གཤེ ['བྱ་ཚིག:གཤེས_མ་འོངས་པ།_ཐ་དད་པ+གཤེ_ད་ལྟ་བ།_ཐ་དད་པ+གཤེ_མ་འོངས་པ།_ཐ་དད་པ+གཤེས_ད་ལྟ་བ།_ཐ་དད་པ']
# གཤེགས ['བྱ་ཚིག:བྱ་ཚིག_###+གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གཤེར ['བྱ་ཚིག:ཤོངས_ད་ལྟ་བ།_ཐ་དད་པ+བཤེར_ད་ལྟ་བ།_ཐ་དད་པ+ཤོགས_ད་ལྟ་བ།_ཐ་དད་པ+ཤེར_ད་ལྟ་བ།_ཐ་དད་པ+གཤེར_ད་ལྟ་བ།_###+གཟུགས་མི་འགྱུར་བ_ཐ་དད་པ']
# གཤེས ['བྱ་ཚིག:གཤེ_སྐུལ་ཚིག_ཐ་དད་པ+གཤེ_འདས་པ།_ཐ་དད་པ+གཤེས_སྐུལ་ཚིག_ཐ་དད་པ+གཤེས_འདས་པ།_ཐ་དད་པ']
# གཤོ ['བྱ་ཚིག:ཤོས_ད་ལྟ་བ།_ཐ་དད་པ+ཤོས_ད་ལྟ་བ།_###+གཤོས_ད་ལྟ་བ།_ཐ་དད་པ+གཤོ_མ་འོངས་པ།_###+བཤོ_ད་ལྟ་བ།_ཐ་དད་པ+གཤོས_མ་འོངས་པ།_ཐ་དད་པ+གཤོ_ད་ལྟ་བ།_ཐ་དད་པ+གཤོ_ད་ལྟ་བ།_###']
# གཤོག ['བྱ་ཚིག:གཤོགས_ད་ལྟ་བ།_ཐ་དད་པ+གཤག_ད་ལྟ་བ།_ཐ་དད་པ+གཤགས_ད་ལྟ་བ།_ཐ་དད་པ+གཤོག_ད་ལྟ་བ།_ཐ་དད་པ']
# གཤོགས ['བྱ་ཚིག:གཤོགས_སྐུལ་ཚིག_ཐ་དད་པ+གཤགས_སྐུལ་ཚིག_ཐ་དད་པ+གཤག_སྐུལ་ཚིག_ཐ་དད་པ+གཤོག_སྐུལ་ཚིག_ཐ་དད་པ']
# གཤོང ['བྱ་ཚིག:གཤོང_ད་ལྟ་བ།_###+གཤོངས_ད་ལྟ་བ།_ཐ་དད་པ+གཤོང_ད་ལྟ་བ།_ཐ་དད་པ+བཤངས_ད་ལྟ་བ།_ཐ་དད་པ+བཤང_ད་ལྟ་བ།_ཐ་དད་པ']
# གཤོངས ['བྱ་ཚིག:བཤངས_སྐུལ་ཚིག_ཐ་དད་པ+གཤོང_སྐུལ་ཚིག_###+གཤོངས_སྐུལ་ཚིག_ཐ་དད་པ+བཤང_སྐུལ་ཚིག_ཐ་དད་པ+གཤོང_སྐུལ་ཚིག_ཐ་དད་པ']
# གཤོམ ['བྱ་ཚིག:ཤོམས_ད་ལྟ་བ།_ཐ་དད་པ+གཤོམ_ད་ལྟ་བ།_ཐ་དད་པ+བཤམ_ད་ལྟ་བ།_ཐ་དད་པ+གཤོམ_ད་ལྟ་བ།_###+བཤམས_ད་ལྟ་བ།_ཐ་དད་པ']
# གཤོར ['བྱ་ཚིག:གཤོར_སྐུལ་ཚིག_###+གཤོར_ད་ལྟ་བ།_###+བཤར_སྐུལ་ཚིག_ཐ་དད་པ+བཤར_སྐུལ་ཚིག_###+གཤོལ_སྐུལ་ཚིག_ཐ་དད་པ+གཤོར_ད་ལྟ་བ།_ཐ་དད་པ+བཤོར_སྐུལ་ཚིག_ཐ་དད་པ+གཤོལ_ད་ལྟ་བ།_ཐ་དད་པ+གཤར_སྐུལ་ཚིག_ཐ་མི་དད་པ+གཤོར_སྐུལ་ཚིག_ཐ་དད་པ+བཤོར_ད་ལྟ་བ།_ཐ་དད་པ']
# གཤོལ ['བྱ་ཚིག:གཤོར_སྐུལ་ཚིག_###+གཤོར_ད་ལྟ་བ།_###+བཤར_སྐུལ་ཚིག_ཐ་དད་པ+བཤར_སྐུལ་ཚིག_###+གཤོལ_སྐུལ་ཚིག_ཐ་དད་པ+གཤོར_ད་ལྟ་བ།_ཐ་དད་པ+བཤོར_སྐུལ་ཚིག_ཐ་དད་པ+གཤོལ_ད་ལྟ་བ།_ཐ་དད་པ+གཤར_སྐུལ་ཚིག_ཐ་མི་དད་པ+གཤོར_སྐུལ་ཚིག_ཐ་དད་པ+བཤོར_ད་ལྟ་བ།_ཐ་དད་པ']
# གཤོས ['བྱ་ཚིག:གཤོ_སྐུལ་ཚིག_###+གཤོ_འདས་པ།_###+གཤོས_སྐུལ་ཚིག_ཐ་དད་པ+གཤོས_འདས་པ།_ཐ་དད་པ']
# གས ['བྱ་ཚིག:གཟུགས་མི་འགྱུར་བ_ཐ་མི་དད་པ']
# གསག ['བྱ་ཚིག:བྱ་ཚིག_ཐ་དད་པ']
# གསང ['བྱ་ཚིག:གསང_ད་ལྟ་བ།_ཐ་དད་པ+གསང_མ་འོངས་པ།_ཐ་དད་པ+གསོངས_ད་ལྟ་བ།_ཐ་དད་པ+གསོངས_མ་འོངས་པ།_ཐ་དད་པ+གསང_འདས་པ།_ཐ་དད་པ+གསོངས_འདས་པ།_ཐ་དད་པ']
# གསངས ['བྱ་ཚིག:བྱ་ཚིག_ཐ་དད་པ']
# གསད ['བྱ་ཚིག:གསོད_མ་འོངས་པ།_###+སོད_མ་འོངས་པ།_ཐ་དད་པ+གསོད_མ་འོངས་པ།_ཐ་དད་པ+གསད_མ་འོངས་པ།_ཐ་དད་པ+བསད_མ་འོངས་པ།_ཐ་དད་པ']
# གསན ['བྱ་ཚིག:གསོན_མ་འོངས་པ།_ཐ་དད་པ+གསོན_ད་ལྟ་བ།_ཐ་དད་པ+གསན_མ་འོངས་པ།_ཐ་དད་པ+གསན_ད་ལྟ་བ།_ཐ་དད་པ+གསན_འདས་པ།_ཐ་དད་པ+གསོན_འདས་པ།_ཐ་དད་པ']
# གསབ ['བྱ་ཚིག:བྱ་ཚིག_ཐ་དད་པ']
# གསིག ['བྱ་ཚིག:བསིག_ད་ལྟ་བ།_ཐ་དད་པ+གསིགས_ད་ལྟ་བ།_ཐ་དད་པ+སིགས_ད་ལྟ་བ།_ཐ་དད་པ+བསིགས_ད་ལྟ་བ།_ཐ་དད་པ+གསིག_ད་ལྟ་བ།_ཐ་དད་པ']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-1bc9c820fe84> in <module>()
#      11     for i in range(len(sub_entries)):
#      12         if sub_entries[i] == 'བྱ' and '༡རྒྱ་གར།' not in sub_entries[i+1]:
# ---> 13             sub.append('བྱ་ཚིག:'+verbs_dict[lemma])
#      14     if sub != []:
#      15         print(lemma, sub)
#
# KeyError: 'གསིགས'

# %%
start = 'གཤོལ'
for line in content1:
    if line.startswith(start+'་ '):
        print(line)
# Out:
# གཤོལ་ | ༡མིང་ཚིག ཞིང་ཁ་རྨོ་སློག་བྱེད་པའི་ཡོ་བྱད་ཅིག་གི་མིང་སྟེ། གཤོལ་དང་། ཐོང་གཤོལ། ཡུལ་སྐད་འགར་ཐོང་ཡང་ཟེར།      དཔེར་ན། ཐོང་གཤོལ་གྱིས་ཞིང་ཁ་རྨོས། གཤོལ་དང་གཉའ་ཤིང་ལྟ་བུ། ༡བྱ་ཚིག ༡བྱ་བྱེད་ཐ་དད་པ། གཤོལ་གྱི་སྐུལ་ཚིག་གི་འབྲི་ཚུལ་གཞན།

# %%
target = 'གཤོལ'+'_'+'སྐུལ་ཚིག'
for verb in verbs_dict.keys():
    if target in verbs_dict[verb]:
        print(verb)
# Out:
# གཤོར

# %%
verbs_dict['ཁྲོབས'] = verbs_dict['ཁྲོབ']
verbs_dict['གདོམས'] = verbs_dict['འདོམ']
verbs_dict['གཞོར'] = verbs_dict['བཞོར']
verbs_dict['གཞོས'] = verbs_dict['ཞོས']
verbs_dict['གཤོལ'] = verbs_dict['གཤོར']
#verbs_dict[] = verbs_dict[]

# %%
alternative = []
for verb in verbs:
    if 'འབྲི་ཚུལ་' in verb:
        alternative.append(verb)

# %%
with open('alternative_verbs.txt', 'w', -1, 'utf-8-sig') as f:
    for line in alternative:
        f.write(line+'\n')

# %%
print(len(alternative))
# Out:
# 160

# %%
verbs_dict['ཁྱགས']
# Out:
# 'བྱ་ཚིག_ཐ་མི་དད་པ'
