# %%
import re

# %%
class pseudoWylie:
    '''to and from pseudo Wylie'''
    
    def __init__(self, string):    
        self.string = string
        
        # characters inserted by converting unicode into wylie
        self.nonwylie_separator = '\[\#\]'
        self.space = ' '
        self.new_nonwylie = ' [#]'

        self.punct_beginning = r'([\@\u0fd3][\#\u0fd4]+[\/_]+|[\%\$\!]+)' #["༄", "༅", "࿓", "࿔", "༇", "༆", "༈"]
        self.p_b_punct = '*'
        self.new_beginning = '@#/_/'

        self.punct_separators = r'(\/_\/(?!\/)|\/\/?\_?(?!\/\/)|\;\_\;|\u0f10\_\u0f10|\|\_\||\:\_)' # [" ", "།", "༎", "༏", "༐", "༑", "༔"]
        self.p_m_punct = ';'
        self.new_middle = '/_/'

        self.punct_other = r'[\(\)\u0f12\u0f13]+' # ["༼", "༽", "༒", "༓"]
        self.p_o_punct = '-'
        self.new_other = ''

        self.w_e_punct = '//_//'
        self.p_e_punct = '.'
        self.new_end = '//_//'
        
        self.syl_punct = r'[\u0f7f \*]+' # ["་", "༌", "ཿ"]
        self.w_space = 'X'

        self.w_aa = "'"
        self.p_aa = 'v'

        self.w_plus = '+'
        self.p_plus = 'x'

    def from_p_w(self):
        words = self.string.replace(self.space, self.new_nonwylie)
        spaces = words.replace(self.w_space, self.space)
        aa = spaces.replace(self.p_aa, self.w_aa)
        b_punct = aa.replace(self.p_b_punct, self.new_beginning)
        m_punct = b_punct.replace(self.p_m_punct, self.new_middle)
        o_punct = m_punct.replace(self.p_o_punct, self.new_other)
        e_punct = o_punct.replace(self.p_e_punct, self.new_end)
        plus = e_punct.replace(self.p_plus, self.w_plus)
        return plus

    def to_p_w(self):
        spaces = re.sub(self.syl_punct, self.w_space, self.string) # inter-word spaces
        words = re.sub(r''+self.w_space+'*'+self.nonwylie_separator, self.space, spaces)
        aa = words.replace(self.w_aa, self.p_aa) # ' > v
        b_punct = re.sub(self.punct_beginning, self.p_b_punct, aa)
        m_punct = re.sub(self.punct_separators, self.p_m_punct, b_punct) # middle punctuation > ;
        o_punct = re.sub(self.punct_other, self.p_o_punct, m_punct) # other punct > -
        e_punct = o_punct.replace(self.w_e_punct, self.p_e_punct) # add ending punctuation
        plus = e_punct.replace(self.w_plus, self.p_plus) # + > f
        extra_spaces = re.sub(r''+self.w_space+'([\\'+self.p_m_punct+'\\'+self.p_e_punct+'\\'+self.p_o_punct+'\\'+self.p_b_punct+'])', r'\1', plus) # remove spaces (x) in front of punctuation
        return extra_spaces

# %%
with open('A1_wylie.txt', 'r', -1, 'utf-8-sig') as f:
    content = [line.strip() for line in f.readlines()]

# %%
for line in content:
    li = pseudoWylie(line).to_p_w()
    print(li)
    print(line)
    print(pseudoWylie(li).from_p_w())
    print()
# Out:
# oM; snangXsrid rnamXdag rangXbzhin lhun grubXpavi;
# oM/[#]snang srid [#]rnam dag [#]rang bzhin [#]lhun [#]grub pa'i//
# oM/_/ [#]snang srid [#]rnam dag [#]rang bzhin [#]lhun [#]grub pa'i/_/
#
# bkraXshis phyogsXbcuvi zhing na bzhugsXpa yi;
# bkra shis [#]phyogs bcu'i [#]zhing [#]na [#]bzhugs pa [#]yi//
# bkra shis [#]phyogs bcu'i [#]zhing [#]na [#]bzhugs pa [#]yi/_/
#
# sangsXrgyas chos dang dgeXvdun vphagsXpavi tshogs;
# sangs rgyas [#]chos [#]dang [#]dge 'dun [#]'phags pa'i [#]tshogs//
# sangs rgyas [#]chos [#]dang [#]dge 'dun [#]'phags pa'i [#]tshogs/_/
#
# kun la phyag vtshal bdagXcag bkraXshis shog;
# kun [#]la [#]phyag [#]'tshal [#]bdag cag [#]bkra shis [#]shog/
# kun [#]la [#]phyag [#]'tshal [#]bdag cag [#]bkra shis [#]shog/_/
#
# sgronXmevi rgyalXpo rtsal brtan donXgrub dgongs;
# sgron me'i [#]rgyal po [#]rtsal [#]brtan [#]don grub [#]dgongs//
# sgron me'i [#]rgyal po [#]rtsal [#]brtan [#]don grub [#]dgongs/_/
#
# byamsXpavi rgyan dpal dgeXgrags dpal damXpa;
# byams pa'i [#]rgyan [#]dpal [#]dge grags [#]dpal [#]dam pa//
# byams pa'i [#]rgyan [#]dpal [#]dge grags [#]dpal [#]dam pa/_/
#
# kun la dgongsXpa rgyaXcher gragsXpa can;
# kun [#]la [#]dgongs pa [#]rgya cher [#]grags pa [#]can//
# kun [#]la [#]dgongs pa [#]rgya cher [#]grags pa [#]can/_/
#
# lhunXpo ltar vphags rtsalXgrags dpal dang ni;
# lhun po [#]ltar [#]'phags [#]rtsal grags [#]dpal [#]dang [#]ni//
# lhun po [#]ltar [#]'phags [#]rtsal grags [#]dpal [#]dang [#]ni/_/
#
# semsXcan thamsXcad la dgongs gragsXpavi dpal;
# sems can [#]thams cad [#]la [#]dgongs [#]grags pa'i [#]dpal//
# sems can [#]thams cad [#]la [#]dgongs [#]grags pa'i [#]dpal/_/
#
# yidXtshim mdzadXpa rtsal rab gragsXdpal te;
# yid tshim [#]mdzad pa [#]rtsal [#]rab [#]grags dpal [#]te//
# yid tshim [#]mdzad pa [#]rtsal [#]rab [#]grags dpal [#]te/_/
#
# mtshan tsam thosXpas bkraXshis dpal vphelXba;
# mtshan [#]tsam [#]thos pas [#]bkra shis [#]dpal [#]'phel ba//
# mtshan [#]tsam [#]thos pas [#]bkra shis [#]dpal [#]'phel ba/_/
#
# bdeXbarXgshegsXpa brgyad la phyag vtshal lo;
# bde bar gshegs pa [#]brgyad [#]la [#]phyag [#]'tshal [#]lo//
# bde bar gshegs pa [#]brgyad [#]la [#]phyag [#]'tshal [#]lo/_/
#
# vjamXdpal gzhonXnu dpalXldan rdoXrjeXvdzin;
# 'jam dpal [#]gzhon nu [#]dpal ldan [#]rdo rje 'dzin//
# 'jam dpal [#]gzhon nu [#]dpal ldan [#]rdo rje 'dzin/_/
#
# spyanXrasXgzigs dbang mgonXpo byamsXpavi dpal;
# spyan ras gzigs [#]dbang [#]mgon po [#]byams pa'i [#]dpal//
# spyan ras gzigs [#]dbang [#]mgon po [#]byams pa'i [#]dpal/_/
#
# saXyi snyingXpo sgribXpa rnamXpar sel;
# sa yi [#]snying po [#]sgrib pa [#]rnam par [#]sel//
# sa yi [#]snying po [#]sgrib pa [#]rnam par [#]sel/_/
#
# namXmkhavi snyingXpo vphagsXmchog kunXtuXbzang;
# nam mkha'i [#]snying po [#]'phags mchog [#]kun tu bzang //
# nam mkha'i [#]snying po [#]'phags mchog [#]kun tu bzang/_/
#
# utxpal rdoXrje padXdkar kluXshing dang;
# ut+pal [#]rdo rje [#]pad dkar [#]klu shing [#]dang //
# ut+pal [#]rdo rje [#]pad dkar [#]klu shing [#]dang/_/
#
# norXbu zlaXba ralXgri nyiXma yi;
# nor bu [#]zla ba [#]ral gri [#]nyi ma [#]yi//
# nor bu [#]zla ba [#]ral gri [#]nyi ma [#]yi/_/
#
# phyagXmtshan legs bsnams bkraXshis dpal gyi mchog;
# phyag mtshan [#]legs [#]bsnams [#]bkra shis [#]dpal [#]gyi [#]mchog/
# phyag mtshan [#]legs [#]bsnams [#]bkra shis [#]dpal [#]gyi [#]mchog/_/
#
# byangXchubXsemsXdpav brgyad la phyag vtshal lo;
# byang chub sems dpa' [#]brgyad [#]la [#]phyag [#]'tshal [#]lo//
# byang chub sems dpa' [#]brgyad [#]la [#]phyag [#]'tshal [#]lo/_/
#
# rinXchen gdugs mchog bkraXshis gser gyi nya;
# rin chen [#]gdugs [#]mchog [#]bkra shis [#]gser [#]gyi [#]nya//
# rin chen [#]gdugs [#]mchog [#]bkra shis [#]gser [#]gyi [#]nya/_/
#
# vdod vbyung bum bzang yidXvong kaXmaXla;
# 'dod [#]'byung [#]bum [#]bzang [#]yid 'ong [#]ka ma la//
# 'dod [#]'byung [#]bum [#]bzang [#]yid 'ong [#]ka ma la/_/
#
# snyanXgrags dung dang phunXtshogs dpalXbevu;
# snyan grags [#]dung [#]dang [#]phun tshogs [#]dpal be'u//
# snyan grags [#]dung [#]dang [#]phun tshogs [#]dpal be'u/_/
#
# miXnub rgyalXmtshan dbang bsgyur vkhorXlo ste;
# mi nub [#]rgyal mtshan [#]dbang [#]bsgyur [#]'khor lo [#]ste//
# mi nub [#]rgyal mtshan [#]dbang [#]bsgyur [#]'khor lo [#]ste/_/
#
# rinXchen rtags mchog brgyad kyi phyagXmtshan can;
# rin chen [#]rtags [#]mchog [#]brgyad [#]kyi [#]phyag mtshan [#]can//
# rin chen [#]rtags [#]mchog [#]brgyad [#]kyi [#]phyag mtshan [#]can/_/
#
# phyogs dus rgyalXba mchod cing dgyes bskyed ma;
# phyogs [#]dus [#]rgyal ba [#]mchod [#]cing [#]dgyes [#]bskyed [#]ma//
# phyogs [#]dus [#]rgyal ba [#]mchod [#]cing [#]dgyes [#]bskyed [#]ma/_/
#
# sgeg sogs ngoXbo dranXpavi dpal vphelXba;
# sgeg [#]sogs [#]ngo bo [#]dran pa'i [#]dpal [#]'phel ba//
# sgeg [#]sogs [#]ngo bo [#]dran pa'i [#]dpal [#]'phel ba/_/
#
# bkraXshis lhaXmo brgyad la phyag vtshal lo;
# bkra shis [#]lha mo [#]brgyad [#]la [#]phyag [#]'tshal [#]lo//
# bkra shis [#]lha mo [#]brgyad [#]la [#]phyag [#]'tshal [#]lo/_/
#
# tshangsXpa chenXpo bdeXvbyung sredXmed bu;
# tshangs pa [#]chen po [#]bde 'byung [#]sred med [#]bu//
# tshangs pa [#]chen po [#]bde 'byung [#]sred med [#]bu/_/
#
# mig stong ldan dang rgyalXpo yulXvkhor srung;
# mig [#]stong [#]ldan [#]dang [#]rgyal po [#]yul 'khor [#]srung //
# mig [#]stong [#]ldan [#]dang [#]rgyal po [#]yul 'khor [#]srung/_/
#
# vphagsXskyesXpo dang kluXdbang mig miXbzang;
# 'phags skyes po [#]dang [#]klu dbang [#]mig [#]mi bzang //
# 'phags skyes po [#]dang [#]klu dbang [#]mig [#]mi bzang/_/
#
# rnamXthos sras te lhaXrdzas vkhorXlo dang;
# rnam thos [#]sras [#]te [#]lha rdzas [#]'khor lo [#]dang //
# rnam thos [#]sras [#]te [#]lha rdzas [#]'khor lo [#]dang/_/
#
# triXshuXla dang mdungXthung rdoXrje can;
# tri shu la [#]dang [#]mdung thung [#]rdo rje [#]can//
# tri shu la [#]dang [#]mdung thung [#]rdo rje [#]can/_/
#
# piXwaM ralXgri mchodXrten rgyalXmtshan vdzin;
# pi waM [#]ral gri [#]mchod rten [#]rgyal mtshan [#]'dzin//
# pi waM [#]ral gri [#]mchod rten [#]rgyal mtshan [#]'dzin/_/
#
# sa gsum gnas su bkraXshis dgeXlegs vphel;
# sa [#]gsum [#]gnas [#]su [#]bkra shis [#]dge legs [#]'phel//
# sa [#]gsum [#]gnas [#]su [#]bkra shis [#]dge legs [#]'phel/_/
#
# vjigXrten skyongXba brgyad la phyag vtshal lo;
# 'jig rten [#]skyong ba [#]brgyad [#]la [#]phyag [#]'tshal [#]lo//
# 'jig rten [#]skyong ba [#]brgyad [#]la [#]phyag [#]'tshal [#]lo/_/
#
# bdag cag deng vdir byaXba brtsomsXpa la;
# bdag [#]cag [#]deng [#]'dir [#]bya ba [#]brtsoms pa [#]la//
# bdag [#]cag [#]deng [#]'dir [#]bya ba [#]brtsoms pa [#]la/_/
#
# bgegs dang nyeXbar vtsheXba kun zhi nas;
# bgegs [#]dang [#]nye bar [#]'tshe ba [#]kun [#]zhi [#]nas//
# bgegs [#]dang [#]nye bar [#]'tshe ba [#]kun [#]zhi [#]nas/_/
#
# vdodXdon dpal vphel bsamXdon yidXbzhin vgrub;
# 'dod don [#]dpal [#]'phel [#]bsam don [#]yid bzhin [#]'grub//
# 'dod don [#]dpal [#]'phel [#]bsam don [#]yid bzhin [#]'grub/_/
#
# bkraXshis bdeXlegs phunXsum tshogsXpar shog;
# bkra shis [#]bde legs [#]phun sum [#]tshogs par [#]shog/
# bkra shis [#]bde legs [#]phun sum [#]tshogs par [#]shog/_/

# %%
import re
l1 = []
l2 = []

text = "རྗེ་བཙུན་བླ་མ་དམིགས་པ་མེད་པའི་ཐུགས་རྗེ་ཆེན་པོ་དང་ལྡན་པ་རྣམས་ལ་ཕྱག་འཚལ་ལོ། །རིག་འཛིན"
lexicon = [["རྗེ", "བཙུན"], ["བླ", "མ"], ["དམིགས", "པ"], ["མེད", "པ"], ["ཐུགས", "རྗེ"], ["ཆེན", "པོ"], ["དང"], ["ལྡན", "པ"], ["རྣམས"], ["།", " "], ["།", " ", "།"], ["།"], ["ལ"], ["ཕྱག"], ["འཚལ"]]

text1 = re.sub(r"([།|༎|༏|༐|༑|༔|\s]+)", "་\g<1>་", text)
print(text1)
l1 = re.split(r"་+", text1)

def process(list1, list2, num):
    list2.append("་".join(l1[:num])+"་")
    del list1[:num]

while len(l1) > 0:
    if   l1[:4] in lexicon: process(l1, l2, 4)
    elif l1[:3] in lexicon: process(l1, l2, 3)
    elif l1[:2] in lexicon: process(l1, l2, 2)
    elif l1[:1] in lexicon: process(l1, l2, 1)
    elif l1[:1] not in lexicon:
        l2.append("་".join(l1[:1])+"་*")
        del l1[:1]

yo = " ".join(l2)
print(yo)
# Out:
# རྗེ་བཙུན་བླ་མ་དམིགས་པ་མེད་པའི་ཐུགས་རྗེ་ཆེན་པོ་དང་ལྡན་པ་རྣམས་ལ་ཕྱག་འཚལ་ལོ་། །་རིག་འཛིན
# རྗེ་བཙུན་ བླ་མ་ དམིགས་པ་ མེད་* པའི་* ཐུགས་རྗེ་ ཆེན་པོ་ དང་ ལྡན་པ་ རྣམས་ ལ་ ཕྱག་ འཚལ་ ལོ་* ། །་* རིག་* འཛིན་*
